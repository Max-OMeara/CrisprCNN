# %%
# ==== Import libraries ====
import math
import random
from typing import Dict, List, Tuple

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F

RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

# %%
# ==== Check GPU/CUDA availability ====
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU device: {torch.cuda.get_device_name(0)}")
    print(f"GPU count: {torch.cuda.device_count()}")
else:
    print("Training will use CPU")
# Out:
# PyTorch version: 2.9.1+cu130
# CUDA available: True
# CUDA version: 13.0
# GPU device: NVIDIA GeForce RTX 4070 Ti SUPER
# GPU count: 1

# %%
DATA_CSV = "data/GenomeCRISPR_+_strands.csv"
SEQ_LEN  = 23
VAL_FRAC = 0.10
TEST_FRAC= 0.10

# Columns in your file:
seq_col   = "sequence"
cell_col  = "cellline"
phen_col  = "condition"   # phenotype
chr_col   = "chr"
strand_col= "strand"      # strand (if available)
target_col= "log2fc"      # target

# Read & keep only what we need
df = pd.read_csv(DATA_CSV, low_memory=False)
required_cols = [seq_col, cell_col, phen_col, chr_col, target_col]
optional_cols = [strand_col]

# Check for required columns
missing = [c for c in required_cols if c not in df.columns]
if missing:
    raise KeyError(f"Missing expected columns: {missing}. Got: {list(df.columns)}")

# Check for optional columns (strand)
has_strand = strand_col in df.columns
cols_to_keep = required_cols + ([strand_col] if has_strand else [])

df = df[cols_to_keep].copy()
df = df.dropna(subset=required_cols)

# Clean sequences: uppercase A/C/G/T and enforce length 23
df[seq_col] = df[seq_col].astype(str).str.upper().str.strip()
df = df[df[seq_col].str.len() == SEQ_LEN]
df = df[df[seq_col].str.match(r"^[ACGT]+$")]

# Factorize categoricals (one-liners)
cell_codes, cell_uniques = pd.factorize(df[cell_col].astype(str).str.strip(), sort=True)
phen_codes, phen_uniques = pd.factorize(df[phen_col].astype(str).str.strip(), sort=True)
# cast chr to string so 10/11/X/Y are handled uniformly
chr_codes,  chr_uniques  = pd.factorize(df[chr_col].astype(str).str.strip(),  sort=True)

# Factorize strand if available, otherwise create dummy
if has_strand:
    strand_codes, strand_uniques = pd.factorize(df[strand_col].astype(str).str.strip(), sort=True)
    n_strand = len(strand_uniques)
else:
    # Create dummy strand codes (all zeros) if not available
    strand_codes = np.zeros(len(df), dtype=np.int64)
    strand_uniques = np.array(["+"] if "+" in str(df.get(strand_col, "+").iloc[0] if len(df) > 0 else "+") else ["+"])
    n_strand = 1

n_cell, n_ph, n_chr = len(cell_uniques), len(phen_uniques), len(chr_uniques)

# One-hot the 23-mer sequences
BASE2IDX = {"A":0, "C":1, "G":2, "T":3}
def onehot_batch(seqs, L=SEQ_LEN):
    N = len(seqs)
    X = np.zeros((N, 4, L), dtype=np.float32)
    for i, s in enumerate(seqs):
        for j, ch in enumerate(s):
            X[i, BASE2IDX[ch], j] = 1.0
    return X

X_seq = onehot_batch(df[seq_col].tolist())
X_cell = cell_codes.astype(np.int64)
X_ph   = phen_codes.astype(np.int64)
X_chr  = chr_codes.astype(np.int64)
X_strand = strand_codes.astype(np.int64)
y      = df[target_col].astype(np.float32).to_numpy()

# Simple random split
idx_all = np.arange(len(df))
idx_train, idx_test = train_test_split(idx_all, test_size=TEST_FRAC, random_state=42)
idx_train, idx_val  = train_test_split(idx_train, test_size=VAL_FRAC/(1-TEST_FRAC), random_state=42)

def take(a, idx): return a[idx]
Xtr_seq, Xva_seq, Xte_seq = take(X_seq, idx_train), take(X_seq, idx_val), take(X_seq, idx_test)
Xtr_cel, Xva_cel, Xte_cel = take(X_cell, idx_train), take(X_cell, idx_val), take(X_cell, idx_test)
Xtr_ph,  Xva_ph,  Xte_ph  = take(X_ph,  idx_train), take(X_ph,  idx_val), take(X_ph,  idx_test)
Xtr_chr, Xva_chr, Xte_chr = take(X_chr, idx_train), take(X_chr, idx_val), take(X_chr, idx_test)
Xtr_str, Xva_str, Xte_str = take(X_strand, idx_train), take(X_strand, idx_val), take(X_strand, idx_test)
y_tr,    y_va,    y_te    = take(y,     idx_train), take(y,     idx_val), take(y,     idx_test)

# Standardize targets using training set statistics
mu = y_tr.mean()
sigma = y_tr.std()
y_tr_norm = (y_tr - mu) / sigma
y_va_norm = (y_va - mu) / sigma
y_te_norm = (y_te - mu) / sigma

# Create full normalized array for easy indexing
y_norm = np.zeros_like(y)
y_norm[idx_train] = y_tr_norm
y_norm[idx_val] = y_va_norm
y_norm[idx_test] = y_te_norm

print(f"train={len(idx_train)}  val={len(idx_val)}  test={len(idx_test)}")
print(f"cells={n_cell}  phenotypes={n_ph}  chrs={n_chr}  strands={n_strand}")
print(f"Target stats: mu={mu:.4f}, sigma={sigma:.4f}")
# Out:
# train=29452509  val=3681564  test=3681564
# cells=420  phenotypes=34  chrs=279  strands=3
# Target stats: mu=-0.0878, sigma=0.8148

# %%
class CrisprCNN(nn.Module):
    def __init__(self, base_channels=48, 
                 n_cell=420, n_phen=34, n_chr=301, n_strand=2,
                 emb_dim=16, dropout=0.3):
        super().__init__()
        
        self.conv2d_1 = nn.Sequential(
            nn.Conv2d(1, base_channels, kernel_size=(3, 3), padding=(1, 1)),
            nn.BatchNorm2d(base_channels),
            nn.ReLU(),
            nn.Dropout(dropout * 0.2)
        )
        
        self.conv2d_2 = nn.Sequential(
            nn.Conv2d(base_channels, base_channels * 2, kernel_size=(3, 3), padding=(1, 1)),
            nn.BatchNorm2d(base_channels * 2),
            nn.ReLU(),
            nn.Dropout(dropout * 0.2)
        )
        
        self.conv2d_3 = nn.Sequential(
            nn.Conv2d(base_channels * 2, base_channels * 2, kernel_size=(3, 3), padding=(1, 1)),
            nn.BatchNorm2d(base_channels * 2),
            nn.ReLU(),
            nn.Dropout(dropout * 0.2)
        )
        
        self.conv2d_4 = nn.Sequential(
            nn.Conv2d(base_channels * 2, base_channels * 2, kernel_size=(3, 3), padding=(1, 1)),
            nn.BatchNorm2d(base_channels * 2),
            nn.ReLU()
        )
        
        self.conv_multi1 = nn.Conv2d(base_channels * 2, base_channels, kernel_size=(1, 1))
        self.conv_multi2 = nn.Conv2d(base_channels * 2, base_channels, kernel_size=(3, 3), padding=(1, 1))
        
        seq_features = base_channels * 2
        
        self.cell_emb = nn.Embedding(n_cell, emb_dim)
        self.phen_emb = nn.Embedding(n_phen, emb_dim)
        self.chr_emb = nn.Embedding(n_chr, emb_dim)
        self.strand_emb = nn.Embedding(n_strand, emb_dim)
        
        total_features = seq_features + (emb_dim * 4)
        
        # Moderate feature processing layers
        self.feature_layers = nn.Sequential(
            nn.Linear(total_features, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(128, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(dropout * 0.7),
            nn.Linear(64, 32),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.Dropout(dropout * 0.5)
        )
        
        # Final prediction head
        self.head = nn.Linear(32, 1)

    def forward(self, seq4x23, cell_idx, phen_idx, chr_idx, strand_idx):
        x = seq4x23.unsqueeze(1)  # (B, 1, 4, 23)
        
        # Conv2D processing
        x = self.conv2d_1(x)  # (B, base_channels, 4, 23)
        x = self.conv2d_2(x)  # (B, base_channels*2, 4, 23)
        x = self.conv2d_3(x)  # (B, base_channels*2, 4, 23)
        x = self.conv2d_4(x)  # (B, base_channels*2, 4, 23)
        
        x1 = self.conv_multi1(x)  # (B, base_channels, 4, 23)
        x2 = self.conv_multi2(x)  # (B, base_channels, 4, 23)
        
        # Pool each branch
        x1_pooled = F.adaptive_avg_pool2d(x1, 1).squeeze(-1).squeeze(-1)  # (B, base_channels)
        x2_pooled = F.adaptive_avg_pool2d(x2, 1).squeeze(-1).squeeze(-1)  # (B, base_channels)
        
        # Concatenate multi-scale features
        x_seq = torch.cat([x1_pooled, x2_pooled], dim=1)  # (B, base_channels * 2)
        
        # Categorical embeddings
        x_cell = self.cell_emb(cell_idx)    # (B, emb_dim)
        x_phen = self.phen_emb(phen_idx)    # (B, emb_dim)
        x_chr = self.chr_emb(chr_idx)       # (B, emb_dim)
        x_strand = self.strand_emb(strand_idx)  # (B, emb_dim)
        
        # Concatenate all features
        x = torch.cat([x_seq, x_cell, x_phen, x_chr, x_strand], dim=1)  # (B, total_features)
        
        # Feature processing
        x = self.feature_layers(x)  # (B, 32)
        
        # Final prediction
        return self.head(x).squeeze(-1)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model = CrisprCNN(base_channels=48, 
                       n_cell=n_cell, n_phen=n_ph, n_chr=n_chr, n_strand=n_strand,
                       emb_dim=16, dropout=0.3).to(device)
print("params:", sum(p.numel() for p in model.parameters()))
# Out:
# Using device: cuda
# params: 298177

# %%
criterion = nn.MSELoss(reduction="mean")

LEARNING_RATE = 3e-4
WEIGHT_DECAY = 1e-4
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

EPOCHS = 20
BATCH  = 512

def iter_minibatches(indexes, batch_size=256, shuffle=True, epoch=None, use_normalized=True):
    """
    Generate minibatches. If use_normalized=True, returns normalized targets.
    """
    idx = np.asarray(indexes)
    if shuffle:
        if epoch is not None:
            rng = np.random.default_rng(42 + epoch)
        else:
            rng = np.random.default_rng()
        rng.shuffle(idx)
    
    target_array = y_norm if use_normalized else y
    
    for start in range(0, len(idx), batch_size):
        mb = idx[start:start+batch_size]
        yield (
            torch.from_numpy(X_seq[mb]).to(device),           # (B, 4, 23) float32
            torch.from_numpy(X_cell[mb]).long().to(device),   # (B,) int64
            torch.from_numpy(X_ph[mb]).long().to(device),     # (B,) int64
            torch.from_numpy(X_chr[mb]).long().to(device),    # (B,) int64
            torch.from_numpy(X_strand[mb]).long().to(device), # (B,) int64
            torch.from_numpy(target_array[mb]).to(device),    # (B,) float32
        )

import time

for epoch in range(1, EPOCHS + 1):
    epoch_start = time.time()
    print(f"\n{'='*60}")
    print(f"Epoch {epoch:02d}/{EPOCHS}")
    print(f"{'='*60}")
    
    model.train()
    train_sum, n_train = 0.0, 0
    batch_count = 0
    total_train_batches = len(idx_train) // BATCH + (1 if len(idx_train) % BATCH != 0 else 0)
    last_update_time = time.time()
    
    for seq, cl, ph, ch, st, tgt_norm in iter_minibatches(idx_train, batch_size=BATCH, shuffle=True, epoch=epoch, use_normalized=True):
        pred_norm = model(seq, cl, ph, ch, st)
        loss = criterion(pred_norm, tgt_norm)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_sum += loss.item() * tgt_norm.size(0)
        n_train   += tgt_norm.size(0)
        batch_count += 1
        
        # Progress update every 100 batches or every 30 seconds
        current_time = time.time()
        if batch_count % 100 == 0 or (current_time - last_update_time) >= 30:
            progress = (batch_count / total_train_batches) * 100
            elapsed = current_time - epoch_start
            batches_per_sec = batch_count / elapsed if elapsed > 0 else 0
            eta_seconds = (total_train_batches - batch_count) / batches_per_sec if batches_per_sec > 0 else 0
            eta_min = int(eta_seconds // 60)
            eta_sec = int(eta_seconds % 60)
            current_loss = train_sum / n_train if n_train > 0 else 0.0
            
            print(f"  Train: [{batch_count:5d}/{total_train_batches}] ({progress:5.1f}%) | "
                  f"Loss: {current_loss:.4f} | "
                  f"Speed: {batches_per_sec:.1f} batches/s | "
                  f"ETA: {eta_min:02d}:{eta_sec:02d}", flush=True)
            last_update_time = current_time

    train_loss = train_sum / n_train if n_train > 0 else 0.0
    train_time = time.time() - epoch_start
    
    # ---- val ----
    print("  Running validation...", flush=True)
    val_start = time.time()
    model.eval()
    val_sum, n_val = 0.0, 0
    val_batch_count = 0
    total_val_batches = len(idx_val) // BATCH + (1 if len(idx_val) % BATCH != 0 else 0)
    
    with torch.no_grad():
        for seq, cl, ph, ch, st, tgt_norm in iter_minibatches(idx_val, batch_size=BATCH, shuffle=False, use_normalized=True):
            pred_norm = model(seq, cl, ph, ch, st)
            loss = criterion(pred_norm, tgt_norm)
            val_sum += loss.item() * tgt_norm.size(0)
            n_val   += tgt_norm.size(0)
            val_batch_count += 1
            
            if val_batch_count % 50 == 0:
                val_progress = (val_batch_count / total_val_batches) * 100
                print(f"    Val: [{val_batch_count:4d}/{total_val_batches}] ({val_progress:5.1f}%)", flush=True)

    val_loss = val_sum / n_val if n_val > 0 else 0.0
    val_time = time.time() - val_start
    total_time = time.time() - epoch_start
    
    # Print epoch summary
    print(f"\n  Epoch {epoch:02d} Summary:")
    print(f"    Train MSE (norm): {train_loss:.4f} | Val MSE (norm): {val_loss:.4f}")
    print(f"    Time: Train={train_time/60:.1f}min, Val={val_time/60:.1f}min, Total={total_time/60:.1f}min")
    print(f"{'='*60}\n", flush=True)
# Out:
# ============================================================
# Epoch 01/20
# ============================================================
#   Train: [  100/57525] (  0.2%) | Loss: 1.0012 | Speed: 52.6 batches/s | ETA: 18:11
#   Train: [  200/57525] (  0.3%) | Loss: 0.9907 | Speed: 73.1 batches/s | ETA: 13:04
#   Train: [  300/57525] (  0.5%) | Loss: 0.9921 | Speed: 83.6 batches/s | ETA: 11:24
#   Train: [  400/57525] (  0.7%) | Loss: 0.9918 | Speed: 90.0 batches/s | ETA: 10:34
#   Train: [  500/57525] (  0.9%) | Loss: 0.9925 | Speed: 94.4 batches/s | ETA: 10:04
#   Train: [  600/57525] (  1.0%) | Loss: 0.9892 | Speed: 97.6 batches/s | ETA: 09:43
#   Train: [  700/57525] (  1.2%) | Loss: 0.9876 | Speed: 99.9 batches/s | ETA: 09:28
#   Train: [  800/57525] (  1.4%) | Loss: 0.9851 | Speed: 101.8 batches/s | ETA: 09:17
#   Train: [  900/57525] (  1.6%) | Loss: 0.9823 | Speed: 103.6 batches/s | ETA: 09:06
#   Train: [ 1000/57525] (  1.7%) | Loss: 0.9811 | Speed: 105.0 batches/s | ETA: 08:58
#   Train: [ 1100/57525] (  1.9%) | Loss: 0.9794 | Speed: 106.4 batches/s | ETA: 08:50
#   Train: [ 1200/57525] (  2.1%) | Loss: 0.9758 | Speed: 107.5 batches/s | ETA: 08:43
#   Train: [ 1300/57525] (  2.3%) | Loss: 0.9747 | Speed: 108.4 batches/s | ETA: 08:38
#   Train: [ 1400/57525] (  2.4%) | Loss: 0.9722 | Speed: 109.3 batches/s | ETA: 08:33
#   Train: [ 1500/57525] (  2.6%) | Loss: 0.9737 | Speed: 110.1 batches/s | ETA: 08:29
#   Train: [ 1600/57525] (  2.8%) | Loss: 0.9728 | Speed: 110.3 batches/s | ETA: 08:27
#   Train: [ 1700/57525] (  3.0%) | Loss: 0.9713 | Speed: 110.5 batches/s | ETA: 08:25
#   Train: [ 1800/57525] (  3.1%) | Loss: 0.9695 | Speed: 110.6 batches/s | ETA: 08:23
#   Train: [ 1900/57525] (  3.3%) | Loss: 0.9675 | Speed: 110.7 batches/s | ETA: 08:22
#   Train: [ 2000/57525] (  3.5%) | Loss: 0.9672 | Speed: 110.8 batches/s | ETA: 08:21
#   Train: [ 2100/57525] (  3.7%) | Loss: 0.9666 | Speed: 110.8 batches/s | ETA: 08:20
#   Train: [ 2200/57525] (  3.8%) | Loss: 0.9673 | Speed: 110.9 batches/s | ETA: 08:18
#   Train: [ 2300/57525] (  4.0%) | Loss: 0.9676 | Speed: 111.2 batches/s | ETA: 08:16
#   Train: [ 2400/57525] (  4.2%) | Loss: 0.9665 | Speed: 111.5 batches/s | ETA: 08:14
#   Train: [ 2500/57525] (  4.3%) | Loss: 0.9656 | Speed: 111.9 batches/s | ETA: 08:11
#   Train: [ 2600/57525] (  4.5%) | Loss: 0.9651 | Speed: 112.1 batches/s | ETA: 08:09
#   Train: [ 2700/57525] (  4.7%) | Loss: 0.9652 | Speed: 112.4 batches/s | ETA: 08:07
#   Train: [ 2800/57525] (  4.9%) | Loss: 0.9647 | Speed: 112.7 batches/s | ETA: 08:05
#   Train: [ 2900/57525] (  5.0%) | Loss: 0.9634 | Speed: 113.0 batches/s | ETA: 08:03
#   Train: [ 3000/57525] (  5.2%) | Loss: 0.9627 | Speed: 113.1 batches/s | ETA: 08:01
#   Train: [ 3100/57525] (  5.4%) | Loss: 0.9617 | Speed: 113.1 batches/s | ETA: 08:01
#   Train: [ 3200/57525] (  5.6%) | Loss: 0.9610 | Speed: 113.3 batches/s | ETA: 07:59
#   Train: [ 3300/57525] (  5.7%) | Loss: 0.9607 | Speed: 113.4 batches/s | ETA: 07:58
#   Train: [ 3400/57525] (  5.9%) | Loss: 0.9605 | Speed: 113.5 batches/s | ETA: 07:57
#   Train: [ 3500/57525] (  6.1%) | Loss: 0.9596 | Speed: 113.5 batches/s | ETA: 07:55
#   Train: [ 3600/57525] (  6.3%) | Loss: 0.9591 | Speed: 113.6 batches/s | ETA: 07:54
#   Train: [ 3700/57525] (  6.4%) | Loss: 0.9593 | Speed: 113.7 batches/s | ETA: 07:53
#   Train: [ 3800/57525] (  6.6%) | Loss: 0.9587 | Speed: 113.9 batches/s | ETA: 07:51
#   Train: [ 3900/57525] (  6.8%) | Loss: 0.9578 | Speed: 114.1 batches/s | ETA: 07:49
#   Train: [ 4000/57525] (  7.0%) | Loss: 0.9566 | Speed: 114.4 batches/s | ETA: 07:47
#   Train: [ 4100/57525] (  7.1%) | Loss: 0.9561 | Speed: 114.6 batches/s | ETA: 07:46
#   Train: [ 4200/57525] (  7.3%) | Loss: 0.9552 | Speed: 114.8 batches/s | ETA: 07:44
#   Train: [ 4300/57525] (  7.5%) | Loss: 0.9547 | Speed: 115.0 batches/s | ETA: 07:42
#   Train: [ 4400/57525] (  7.6%) | Loss: 0.9545 | Speed: 115.0 batches/s | ETA: 07:42
#   Train: [ 4500/57525] (  7.8%) | Loss: 0.9540 | Speed: 115.0 batches/s | ETA: 07:41
#   Train: [ 4600/57525] (  8.0%) | Loss: 0.9542 | Speed: 114.9 batches/s | ETA: 07:40
#   Train: [ 4700/57525] (  8.2%) | Loss: 0.9535 | Speed: 115.0 batches/s | ETA: 07:39
#   Train: [ 4800/57525] (  8.3%) | Loss: 0.9529 | Speed: 114.9 batches/s | ETA: 07:38
#   Train: [ 4900/57525] (  8.5%) | Loss: 0.9520 | Speed: 115.0 batches/s | ETA: 07:37
#   Train: [ 5000/57525] (  8.7%) | Loss: 0.9514 | Speed: 115.1 batches/s | ETA: 07:36
#   Train: [ 5100/57525] (  8.9%) | Loss: 0.9509 | Speed: 115.2 batches/s | ETA: 07:35
#   Train: [ 5200/57525] (  9.0%) | Loss: 0.9506 | Speed: 115.4 batches/s | ETA: 07:33
#   Train: [ 5300/57525] (  9.2%) | Loss: 0.9504 | Speed: 115.5 batches/s | ETA: 07:32
#   Train: [ 5400/57525] (  9.4%) | Loss: 0.9495 | Speed: 115.6 batches/s | ETA: 07:30
#   Train: [ 5500/57525] (  9.6%) | Loss: 0.9498 | Speed: 115.7 batches/s | ETA: 07:29
#   Train: [ 5600/57525] (  9.7%) | Loss: 0.9493 | Speed: 115.9 batches/s | ETA: 07:28
#   Train: [ 5700/57525] (  9.9%) | Loss: 0.9493 | Speed: 116.1 batches/s | ETA: 07:26
#   Train: [ 5800/57525] ( 10.1%) | Loss: 0.9481 | Speed: 116.1 batches/s | ETA: 07:25
#   Train: [ 5900/57525] ( 10.3%) | Loss: 0.9475 | Speed: 116.1 batches/s | ETA: 07:24
#   Train: [ 6000/57525] ( 10.4%) | Loss: 0.9468 | Speed: 116.1 batches/s | ETA: 07:23
#   Train: [ 6100/57525] ( 10.6%) | Loss: 0.9458 | Speed: 116.1 batches/s | ETA: 07:23
#   Train: [ 6200/57525] ( 10.8%) | Loss: 0.9449 | Speed: 116.1 batches/s | ETA: 07:22
#   Train: [ 6300/57525] ( 11.0%) | Loss: 0.9445 | Speed: 116.2 batches/s | ETA: 07:20
#   Train: [ 6400/57525] ( 11.1%) | Loss: 0.9440 | Speed: 116.2 batches/s | ETA: 07:20
#   Train: [ 6500/57525] ( 11.3%) | Loss: 0.9436 | Speed: 116.2 batches/s | ETA: 07:19
#   Train: [ 6600/57525] ( 11.5%) | Loss: 0.9435 | Speed: 116.3 batches/s | ETA: 07:17
#   Train: [ 6700/57525] ( 11.6%) | Loss: 0.9432 | Speed: 116.3 batches/s | ETA: 07:16
#   Train: [ 6800/57525] ( 11.8%) | Loss: 0.9424 | Speed: 116.4 batches/s | ETA: 07:15
#   Train: [ 6900/57525] ( 12.0%) | Loss: 0.9420 | Speed: 116.4 batches/s | ETA: 07:14
#   Train: [ 7000/57525] ( 12.2%) | Loss: 0.9419 | Speed: 116.4 batches/s | ETA: 07:13
#   Train: [ 7100/57525] ( 12.3%) | Loss: 0.9412 | Speed: 116.5 batches/s | ETA: 07:12
#   Train: [ 7200/57525] ( 12.5%) | Loss: 0.9409 | Speed: 116.4 batches/s | ETA: 07:12
#   Train: [ 7300/57525] ( 12.7%) | Loss: 0.9402 | Speed: 116.3 batches/s | ETA: 07:11
#   Train: [ 7400/57525] ( 12.9%) | Loss: 0.9397 | Speed: 116.3 batches/s | ETA: 07:11
#   Train: [ 7500/57525] ( 13.0%) | Loss: 0.9394 | Speed: 116.2 batches/s | ETA: 07:10
#   Train: [ 7600/57525] ( 13.2%) | Loss: 0.9388 | Speed: 116.2 batches/s | ETA: 07:09
#   Train: [ 7700/57525] ( 13.4%) | Loss: 0.9385 | Speed: 116.1 batches/s | ETA: 07:09
#   Train: [ 7800/57525] ( 13.6%) | Loss: 0.9380 | Speed: 116.1 batches/s | ETA: 07:08
#   Train: [ 7900/57525] ( 13.7%) | Loss: 0.9375 | Speed: 116.1 batches/s | ETA: 07:07
#   Train: [ 8000/57525] ( 13.9%) | Loss: 0.9371 | Speed: 116.2 batches/s | ETA: 07:06
#   Train: [ 8100/57525] ( 14.1%) | Loss: 0.9362 | Speed: 116.3 batches/s | ETA: 07:05
#   Train: [ 8200/57525] ( 14.3%) | Loss: 0.9362 | Speed: 116.4 batches/s | ETA: 07:03
#   Train: [ 8300/57525] ( 14.4%) | Loss: 0.9361 | Speed: 116.4 batches/s | ETA: 07:02
#   Train: [ 8400/57525] ( 14.6%) | Loss: 0.9358 | Speed: 116.5 batches/s | ETA: 07:01
#   Train: [ 8500/57525] ( 14.8%) | Loss: 0.9352 | Speed: 116.6 batches/s | ETA: 07:00
#   Train: [ 8600/57525] ( 15.0%) | Loss: 0.9346 | Speed: 116.6 batches/s | ETA: 06:59
#   Train: [ 8700/57525] ( 15.1%) | Loss: 0.9341 | Speed: 116.6 batches/s | ETA: 06:58
#   Train: [ 8800/57525] ( 15.3%) | Loss: 0.9336 | Speed: 116.7 batches/s | ETA: 06:57
#   Train: [ 8900/57525] ( 15.5%) | Loss: 0.9333 | Speed: 116.7 batches/s | ETA: 06:56
#   Train: [ 9000/57525] ( 15.6%) | Loss: 0.9330 | Speed: 116.8 batches/s | ETA: 06:55
#   Train: [ 9100/57525] ( 15.8%) | Loss: 0.9327 | Speed: 116.8 batches/s | ETA: 06:54
#   Train: [ 9200/57525] ( 16.0%) | Loss: 0.9319 | Speed: 116.8 batches/s | ETA: 06:53
#   Train: [ 9300/57525] ( 16.2%) | Loss: 0.9315 | Speed: 116.9 batches/s | ETA: 06:52
#   Train: [ 9400/57525] ( 16.3%) | Loss: 0.9311 | Speed: 116.9 batches/s | ETA: 06:51
#   Train: [ 9500/57525] ( 16.5%) | Loss: 0.9308 | Speed: 117.0 batches/s | ETA: 06:50
#   Train: [ 9600/57525] ( 16.7%) | Loss: 0.9306 | Speed: 117.1 batches/s | ETA: 06:49
#   Train: [ 9700/57525] ( 16.9%) | Loss: 0.9301 | Speed: 117.2 batches/s | ETA: 06:48
#   Train: [ 9800/57525] ( 17.0%) | Loss: 0.9296 | Speed: 117.2 batches/s | ETA: 06:47
#   Train: [ 9900/57525] ( 17.2%) | Loss: 0.9292 | Speed: 117.3 batches/s | ETA: 06:46
#   Train: [10000/57525] ( 17.4%) | Loss: 0.9288 | Speed: 117.3 batches/s | ETA: 06:45
#   Train: [10100/57525] ( 17.6%) | Loss: 0.9284 | Speed: 117.2 batches/s | ETA: 06:44
#   Train: [10200/57525] ( 17.7%) | Loss: 0.9281 | Speed: 117.2 batches/s | ETA: 06:43
#   Train: [10300/57525] ( 17.9%) | Loss: 0.9276 | Speed: 117.1 batches/s | ETA: 06:43
#   Train: [10400/57525] ( 18.1%) | Loss: 0.9272 | Speed: 117.1 batches/s | ETA: 06:42
#   Train: [10500/57525] ( 18.3%) | Loss: 0.9269 | Speed: 117.0 batches/s | ETA: 06:41
#   Train: [10600/57525] ( 18.4%) | Loss: 0.9265 | Speed: 117.0 batches/s | ETA: 06:41
#   Train: [10700/57525] ( 18.6%) | Loss: 0.9258 | Speed: 117.0 batches/s | ETA: 06:40
#   Train: [10800/57525] ( 18.8%) | Loss: 0.9255 | Speed: 117.0 batches/s | ETA: 06:39
#   Train: [10900/57525] ( 18.9%) | Loss: 0.9251 | Speed: 117.0 batches/s | ETA: 06:38
#   Train: [11000/57525] ( 19.1%) | Loss: 0.9250 | Speed: 117.1 batches/s | ETA: 06:37
#   Train: [11100/57525] ( 19.3%) | Loss: 0.9250 | Speed: 117.1 batches/s | ETA: 06:36
#   Train: [11200/57525] ( 19.5%) | Loss: 0.9246 | Speed: 117.2 batches/s | ETA: 06:35
#   Train: [11300/57525] ( 19.6%) | Loss: 0.9241 | Speed: 117.2 batches/s | ETA: 06:34
#   Train: [11400/57525] ( 19.8%) | Loss: 0.9238 | Speed: 117.2 batches/s | ETA: 06:33
#   Train: [11500/57525] ( 20.0%) | Loss: 0.9234 | Speed: 117.1 batches/s | ETA: 06:32
#   Train: [11600/57525] ( 20.2%) | Loss: 0.9228 | Speed: 117.1 batches/s | ETA: 06:32
#   Train: [11700/57525] ( 20.3%) | Loss: 0.9225 | Speed: 117.1 batches/s | ETA: 06:31
#   Train: [11800/57525] ( 20.5%) | Loss: 0.9222 | Speed: 117.1 batches/s | ETA: 06:30
#   Train: [11900/57525] ( 20.7%) | Loss: 0.9217 | Speed: 117.1 batches/s | ETA: 06:29
#   Train: [12000/57525] ( 20.9%) | Loss: 0.9213 | Speed: 117.0 batches/s | ETA: 06:28
#   Train: [12100/57525] ( 21.0%) | Loss: 0.9210 | Speed: 117.0 batches/s | ETA: 06:28
#   Train: [12200/57525] ( 21.2%) | Loss: 0.9205 | Speed: 117.1 batches/s | ETA: 06:27
#   Train: [12300/57525] ( 21.4%) | Loss: 0.9203 | Speed: 117.1 batches/s | ETA: 06:26
#   Train: [12400/57525] ( 21.6%) | Loss: 0.9201 | Speed: 117.1 batches/s | ETA: 06:25
#   Train: [12500/57525] ( 21.7%) | Loss: 0.9198 | Speed: 117.2 batches/s | ETA: 06:24
#   Train: [12600/57525] ( 21.9%) | Loss: 0.9195 | Speed: 117.2 batches/s | ETA: 06:23
#   Train: [12700/57525] ( 22.1%) | Loss: 0.9191 | Speed: 117.3 batches/s | ETA: 06:22
#   Train: [12800/57525] ( 22.3%) | Loss: 0.9189 | Speed: 117.3 batches/s | ETA: 06:21
#   Train: [12900/57525] ( 22.4%) | Loss: 0.9186 | Speed: 117.3 batches/s | ETA: 06:20
#   Train: [13000/57525] ( 22.6%) | Loss: 0.9180 | Speed: 117.3 batches/s | ETA: 06:19
#   Train: [13100/57525] ( 22.8%) | Loss: 0.9176 | Speed: 117.3 batches/s | ETA: 06:18
#   Train: [13200/57525] ( 22.9%) | Loss: 0.9172 | Speed: 117.2 batches/s | ETA: 06:18
#   Train: [13300/57525] ( 23.1%) | Loss: 0.9169 | Speed: 117.2 batches/s | ETA: 06:17
#   Train: [13400/57525] ( 23.3%) | Loss: 0.9166 | Speed: 117.2 batches/s | ETA: 06:16
#   Train: [13500/57525] ( 23.5%) | Loss: 0.9163 | Speed: 117.2 batches/s | ETA: 06:15
#   Train: [13600/57525] ( 23.6%) | Loss: 0.9161 | Speed: 117.3 batches/s | ETA: 06:14
#   Train: [13700/57525] ( 23.8%) | Loss: 0.9158 | Speed: 117.3 batches/s | ETA: 06:13
#   Train: [13800/57525] ( 24.0%) | Loss: 0.9154 | Speed: 117.4 batches/s | ETA: 06:12
#   Train: [13900/57525] ( 24.2%) | Loss: 0.9153 | Speed: 117.4 batches/s | ETA: 06:11
#   Train: [14000/57525] ( 24.3%) | Loss: 0.9148 | Speed: 117.4 batches/s | ETA: 06:10
#   Train: [14100/57525] ( 24.5%) | Loss: 0.9146 | Speed: 117.5 batches/s | ETA: 06:09
#   Train: [14200/57525] ( 24.7%) | Loss: 0.9145 | Speed: 117.5 batches/s | ETA: 06:08
#   Train: [14300/57525] ( 24.9%) | Loss: 0.9142 | Speed: 117.5 batches/s | ETA: 06:07
#   Train: [14400/57525] ( 25.0%) | Loss: 0.9138 | Speed: 117.5 batches/s | ETA: 06:07
#   Train: [14500/57525] ( 25.2%) | Loss: 0.9138 | Speed: 117.5 batches/s | ETA: 06:06
#   Train: [14600/57525] ( 25.4%) | Loss: 0.9134 | Speed: 117.5 batches/s | ETA: 06:05
#   Train: [14700/57525] ( 25.6%) | Loss: 0.9131 | Speed: 117.5 batches/s | ETA: 06:04
#   Train: [14800/57525] ( 25.7%) | Loss: 0.9130 | Speed: 117.5 batches/s | ETA: 06:03
#   Train: [14900/57525] ( 25.9%) | Loss: 0.9128 | Speed: 117.5 batches/s | ETA: 06:02
#   Train: [15000/57525] ( 26.1%) | Loss: 0.9125 | Speed: 117.5 batches/s | ETA: 06:01
#   Train: [15100/57525] ( 26.2%) | Loss: 0.9123 | Speed: 117.5 batches/s | ETA: 06:01
#   Train: [15200/57525] ( 26.4%) | Loss: 0.9120 | Speed: 117.5 batches/s | ETA: 06:00
#   Train: [15300/57525] ( 26.6%) | Loss: 0.9116 | Speed: 117.5 batches/s | ETA: 05:59
#   Train: [15400/57525] ( 26.8%) | Loss: 0.9112 | Speed: 117.5 batches/s | ETA: 05:58
#   Train: [15500/57525] ( 26.9%) | Loss: 0.9113 | Speed: 117.5 batches/s | ETA: 05:57
#   Train: [15600/57525] ( 27.1%) | Loss: 0.9109 | Speed: 117.4 batches/s | ETA: 05:56
#   Train: [15700/57525] ( 27.3%) | Loss: 0.9105 | Speed: 117.4 batches/s | ETA: 05:56
#   Train: [15800/57525] ( 27.5%) | Loss: 0.9104 | Speed: 117.4 batches/s | ETA: 05:55
#   Train: [15900/57525] ( 27.6%) | Loss: 0.9101 | Speed: 117.4 batches/s | ETA: 05:54
#   Train: [16000/57525] ( 27.8%) | Loss: 0.9099 | Speed: 117.3 batches/s | ETA: 05:53
#   Train: [16100/57525] ( 28.0%) | Loss: 0.9097 | Speed: 117.3 batches/s | ETA: 05:53
#   Train: [16200/57525] ( 28.2%) | Loss: 0.9094 | Speed: 117.3 batches/s | ETA: 05:52
#   Train: [16300/57525] ( 28.3%) | Loss: 0.9091 | Speed: 117.3 batches/s | ETA: 05:51
#   Train: [16400/57525] ( 28.5%) | Loss: 0.9088 | Speed: 117.3 batches/s | ETA: 05:50
#   Train: [16500/57525] ( 28.7%) | Loss: 0.9084 | Speed: 117.3 batches/s | ETA: 05:49
#   Train: [16600/57525] ( 28.9%) | Loss: 0.9081 | Speed: 117.3 batches/s | ETA: 05:48
#   Train: [16700/57525] ( 29.0%) | Loss: 0.9079 | Speed: 117.4 batches/s | ETA: 05:47
#   Train: [16800/57525] ( 29.2%) | Loss: 0.9077 | Speed: 117.4 batches/s | ETA: 05:46
#   Train: [16900/57525] ( 29.4%) | Loss: 0.9074 | Speed: 117.4 batches/s | ETA: 05:45
#   Train: [17000/57525] ( 29.6%) | Loss: 0.9072 | Speed: 117.4 batches/s | ETA: 05:45
#   Train: [17100/57525] ( 29.7%) | Loss: 0.9069 | Speed: 117.4 batches/s | ETA: 05:44
#   Train: [17200/57525] ( 29.9%) | Loss: 0.9068 | Speed: 117.4 batches/s | ETA: 05:43
#   Train: [17300/57525] ( 30.1%) | Loss: 0.9065 | Speed: 117.5 batches/s | ETA: 05:42
#   Train: [17400/57525] ( 30.2%) | Loss: 0.9061 | Speed: 117.5 batches/s | ETA: 05:41
#   Train: [17500/57525] ( 30.4%) | Loss: 0.9056 | Speed: 117.5 batches/s | ETA: 05:40
#   Train: [17600/57525] ( 30.6%) | Loss: 0.9054 | Speed: 117.5 batches/s | ETA: 05:39
#   Train: [17700/57525] ( 30.8%) | Loss: 0.9052 | Speed: 117.5 batches/s | ETA: 05:38
#   Train: [17800/57525] ( 30.9%) | Loss: 0.9048 | Speed: 117.5 batches/s | ETA: 05:37
#   Train: [17900/57525] ( 31.1%) | Loss: 0.9045 | Speed: 117.6 batches/s | ETA: 05:37
#   Train: [18000/57525] ( 31.3%) | Loss: 0.9044 | Speed: 117.6 batches/s | ETA: 05:36
#   Train: [18100/57525] ( 31.5%) | Loss: 0.9042 | Speed: 117.6 batches/s | ETA: 05:35
#   Train: [18200/57525] ( 31.6%) | Loss: 0.9040 | Speed: 117.7 batches/s | ETA: 05:34
#   Train: [18300/57525] ( 31.8%) | Loss: 0.9036 | Speed: 117.7 batches/s | ETA: 05:33
#   Train: [18400/57525] ( 32.0%) | Loss: 0.9034 | Speed: 117.7 batches/s | ETA: 05:32
#   Train: [18500/57525] ( 32.2%) | Loss: 0.9030 | Speed: 117.7 batches/s | ETA: 05:31
#   Train: [18600/57525] ( 32.3%) | Loss: 0.9030 | Speed: 117.6 batches/s | ETA: 05:30
#   Train: [18700/57525] ( 32.5%) | Loss: 0.9027 | Speed: 117.6 batches/s | ETA: 05:30
#   Train: [18800/57525] ( 32.7%) | Loss: 0.9025 | Speed: 117.6 batches/s | ETA: 05:29
#   Train: [18900/57525] ( 32.9%) | Loss: 0.9020 | Speed: 117.6 batches/s | ETA: 05:28
#   Train: [19000/57525] ( 33.0%) | Loss: 0.9018 | Speed: 117.5 batches/s | ETA: 05:27
#   Train: [19100/57525] ( 33.2%) | Loss: 0.9015 | Speed: 117.5 batches/s | ETA: 05:26
#   Train: [19200/57525] ( 33.4%) | Loss: 0.9014 | Speed: 117.5 batches/s | ETA: 05:26
#   Train: [19300/57525] ( 33.6%) | Loss: 0.9012 | Speed: 117.6 batches/s | ETA: 05:25
#   Train: [19400/57525] ( 33.7%) | Loss: 0.9010 | Speed: 117.6 batches/s | ETA: 05:24
#   Train: [19500/57525] ( 33.9%) | Loss: 0.9008 | Speed: 117.6 batches/s | ETA: 05:23
#   Train: [19600/57525] ( 34.1%) | Loss: 0.9007 | Speed: 117.6 batches/s | ETA: 05:22
#   Train: [19700/57525] ( 34.2%) | Loss: 0.9005 | Speed: 117.6 batches/s | ETA: 05:21
#   Train: [19800/57525] ( 34.4%) | Loss: 0.9001 | Speed: 117.6 batches/s | ETA: 05:20
#   Train: [19900/57525] ( 34.6%) | Loss: 0.9000 | Speed: 117.6 batches/s | ETA: 05:20
#   Train: [20000/57525] ( 34.8%) | Loss: 0.8999 | Speed: 117.6 batches/s | ETA: 05:19
#   Train: [20100/57525] ( 34.9%) | Loss: 0.8998 | Speed: 117.5 batches/s | ETA: 05:18
#   Train: [20200/57525] ( 35.1%) | Loss: 0.8997 | Speed: 117.5 batches/s | ETA: 05:17
#   Train: [20300/57525] ( 35.3%) | Loss: 0.8995 | Speed: 117.5 batches/s | ETA: 05:16
#   Train: [20400/57525] ( 35.5%) | Loss: 0.8994 | Speed: 117.5 batches/s | ETA: 05:15
#   Train: [20500/57525] ( 35.6%) | Loss: 0.8992 | Speed: 117.5 batches/s | ETA: 05:15
#   Train: [20600/57525] ( 35.8%) | Loss: 0.8991 | Speed: 117.5 batches/s | ETA: 05:14
#   Train: [20700/57525] ( 36.0%) | Loss: 0.8988 | Speed: 117.5 batches/s | ETA: 05:13
#   Train: [20800/57525] ( 36.2%) | Loss: 0.8985 | Speed: 117.6 batches/s | ETA: 05:12
#   Train: [20900/57525] ( 36.3%) | Loss: 0.8983 | Speed: 117.6 batches/s | ETA: 05:11
#   Train: [21000/57525] ( 36.5%) | Loss: 0.8981 | Speed: 117.6 batches/s | ETA: 05:10
#   Train: [21100/57525] ( 36.7%) | Loss: 0.8979 | Speed: 117.6 batches/s | ETA: 05:09
#   Train: [21200/57525] ( 36.9%) | Loss: 0.8977 | Speed: 117.6 batches/s | ETA: 05:08
#   Train: [21300/57525] ( 37.0%) | Loss: 0.8973 | Speed: 117.6 batches/s | ETA: 05:08
#   Train: [21400/57525] ( 37.2%) | Loss: 0.8969 | Speed: 117.6 batches/s | ETA: 05:07
#   Train: [21500/57525] ( 37.4%) | Loss: 0.8968 | Speed: 117.6 batches/s | ETA: 05:06
#   Train: [21600/57525] ( 37.5%) | Loss: 0.8966 | Speed: 117.6 batches/s | ETA: 05:05
#   Train: [21700/57525] ( 37.7%) | Loss: 0.8964 | Speed: 117.6 batches/s | ETA: 05:04
#   Train: [21800/57525] ( 37.9%) | Loss: 0.8964 | Speed: 117.6 batches/s | ETA: 05:03
#   Train: [21900/57525] ( 38.1%) | Loss: 0.8961 | Speed: 117.6 batches/s | ETA: 05:02
#   Train: [22000/57525] ( 38.2%) | Loss: 0.8957 | Speed: 117.6 batches/s | ETA: 05:02
#   Train: [22100/57525] ( 38.4%) | Loss: 0.8955 | Speed: 117.7 batches/s | ETA: 05:01
#   Train: [22200/57525] ( 38.6%) | Loss: 0.8954 | Speed: 117.7 batches/s | ETA: 05:00
#   Train: [22300/57525] ( 38.8%) | Loss: 0.8950 | Speed: 117.7 batches/s | ETA: 04:59
#   Train: [22400/57525] ( 38.9%) | Loss: 0.8948 | Speed: 117.7 batches/s | ETA: 04:58
#   Train: [22500/57525] ( 39.1%) | Loss: 0.8944 | Speed: 117.7 batches/s | ETA: 04:57
#   Train: [22600/57525] ( 39.3%) | Loss: 0.8943 | Speed: 117.7 batches/s | ETA: 04:56
#   Train: [22700/57525] ( 39.5%) | Loss: 0.8942 | Speed: 117.7 batches/s | ETA: 04:55
#   Train: [22800/57525] ( 39.6%) | Loss: 0.8939 | Speed: 117.7 batches/s | ETA: 04:54
#   Train: [22900/57525] ( 39.8%) | Loss: 0.8937 | Speed: 117.7 batches/s | ETA: 04:54
#   Train: [23000/57525] ( 40.0%) | Loss: 0.8934 | Speed: 117.7 batches/s | ETA: 04:53
#   Train: [23100/57525] ( 40.2%) | Loss: 0.8931 | Speed: 117.7 batches/s | ETA: 04:52
#   Train: [23200/57525] ( 40.3%) | Loss: 0.8929 | Speed: 117.7 batches/s | ETA: 04:51
#   Train: [23300/57525] ( 40.5%) | Loss: 0.8927 | Speed: 117.7 batches/s | ETA: 04:50
#   Train: [23400/57525] ( 40.7%) | Loss: 0.8925 | Speed: 117.7 batches/s | ETA: 04:49
#   Train: [23500/57525] ( 40.9%) | Loss: 0.8923 | Speed: 117.7 batches/s | ETA: 04:48
#   Train: [23600/57525] ( 41.0%) | Loss: 0.8921 | Speed: 117.7 batches/s | ETA: 04:48
#   Train: [23700/57525] ( 41.2%) | Loss: 0.8919 | Speed: 117.7 batches/s | ETA: 04:47
#   Train: [23800/57525] ( 41.4%) | Loss: 0.8917 | Speed: 117.8 batches/s | ETA: 04:46
#   Train: [23900/57525] ( 41.5%) | Loss: 0.8914 | Speed: 117.8 batches/s | ETA: 04:45
#   Train: [24000/57525] ( 41.7%) | Loss: 0.8912 | Speed: 117.7 batches/s | ETA: 04:44
#   Train: [24100/57525] ( 41.9%) | Loss: 0.8910 | Speed: 117.7 batches/s | ETA: 04:43
#   Train: [24200/57525] ( 42.1%) | Loss: 0.8909 | Speed: 117.7 batches/s | ETA: 04:43
#   Train: [24300/57525] ( 42.2%) | Loss: 0.8907 | Speed: 117.7 batches/s | ETA: 04:42
#   Train: [24400/57525] ( 42.4%) | Loss: 0.8905 | Speed: 117.6 batches/s | ETA: 04:41
#   Train: [24500/57525] ( 42.6%) | Loss: 0.8902 | Speed: 117.6 batches/s | ETA: 04:40
#   Train: [24600/57525] ( 42.8%) | Loss: 0.8900 | Speed: 117.6 batches/s | ETA: 04:39
#   Train: [24700/57525] ( 42.9%) | Loss: 0.8899 | Speed: 117.6 batches/s | ETA: 04:39
#   Train: [24800/57525] ( 43.1%) | Loss: 0.8896 | Speed: 117.6 batches/s | ETA: 04:38
#   Train: [24900/57525] ( 43.3%) | Loss: 0.8893 | Speed: 117.6 batches/s | ETA: 04:37
#   Train: [25000/57525] ( 43.5%) | Loss: 0.8891 | Speed: 117.6 batches/s | ETA: 04:36
#   Train: [25100/57525] ( 43.6%) | Loss: 0.8889 | Speed: 117.6 batches/s | ETA: 04:35
#   Train: [25200/57525] ( 43.8%) | Loss: 0.8887 | Speed: 117.6 batches/s | ETA: 04:34
#   Train: [25300/57525] ( 44.0%) | Loss: 0.8884 | Speed: 117.7 batches/s | ETA: 04:33
#   Train: [25400/57525] ( 44.2%) | Loss: 0.8883 | Speed: 117.7 batches/s | ETA: 04:33
#   Train: [25500/57525] ( 44.3%) | Loss: 0.8881 | Speed: 117.7 batches/s | ETA: 04:32
#   Train: [25600/57525] ( 44.5%) | Loss: 0.8878 | Speed: 117.7 batches/s | ETA: 04:31
#   Train: [25700/57525] ( 44.7%) | Loss: 0.8876 | Speed: 117.7 batches/s | ETA: 04:30
#   Train: [25800/57525] ( 44.9%) | Loss: 0.8874 | Speed: 117.7 batches/s | ETA: 04:29
#   Train: [25900/57525] ( 45.0%) | Loss: 0.8873 | Speed: 117.7 batches/s | ETA: 04:28
#   Train: [26000/57525] ( 45.2%) | Loss: 0.8871 | Speed: 117.7 batches/s | ETA: 04:27
#   Train: [26100/57525] ( 45.4%) | Loss: 0.8869 | Speed: 117.7 batches/s | ETA: 04:26
#   Train: [26200/57525] ( 45.5%) | Loss: 0.8867 | Speed: 117.8 batches/s | ETA: 04:26
#   Train: [26300/57525] ( 45.7%) | Loss: 0.8864 | Speed: 117.8 batches/s | ETA: 04:25
#   Train: [26400/57525] ( 45.9%) | Loss: 0.8863 | Speed: 117.8 batches/s | ETA: 04:24
#   Train: [26500/57525] ( 46.1%) | Loss: 0.8862 | Speed: 117.8 batches/s | ETA: 04:23
#   Train: [26600/57525] ( 46.2%) | Loss: 0.8859 | Speed: 117.8 batches/s | ETA: 04:22
#   Train: [26700/57525] ( 46.4%) | Loss: 0.8856 | Speed: 117.9 batches/s | ETA: 04:21
#   Train: [26800/57525] ( 46.6%) | Loss: 0.8854 | Speed: 117.8 batches/s | ETA: 04:20
#   Train: [26900/57525] ( 46.8%) | Loss: 0.8852 | Speed: 117.8 batches/s | ETA: 04:19
#   Train: [27000/57525] ( 46.9%) | Loss: 0.8849 | Speed: 117.8 batches/s | ETA: 04:19
#   Train: [27100/57525] ( 47.1%) | Loss: 0.8847 | Speed: 117.8 batches/s | ETA: 04:18
#   Train: [27200/57525] ( 47.3%) | Loss: 0.8846 | Speed: 117.8 batches/s | ETA: 04:17
#   Train: [27300/57525] ( 47.5%) | Loss: 0.8843 | Speed: 117.8 batches/s | ETA: 04:16
#   Train: [27400/57525] ( 47.6%) | Loss: 0.8841 | Speed: 117.8 batches/s | ETA: 04:15
#   Train: [27500/57525] ( 47.8%) | Loss: 0.8839 | Speed: 117.8 batches/s | ETA: 04:14
#   Train: [27600/57525] ( 48.0%) | Loss: 0.8838 | Speed: 117.8 batches/s | ETA: 04:13
#   Train: [27700/57525] ( 48.2%) | Loss: 0.8837 | Speed: 117.8 batches/s | ETA: 04:13
#   Train: [27800/57525] ( 48.3%) | Loss: 0.8835 | Speed: 117.8 batches/s | ETA: 04:12
#   Train: [27900/57525] ( 48.5%) | Loss: 0.8832 | Speed: 117.8 batches/s | ETA: 04:11
#   Train: [28000/57525] ( 48.7%) | Loss: 0.8829 | Speed: 117.8 batches/s | ETA: 04:10
#   Train: [28100/57525] ( 48.8%) | Loss: 0.8826 | Speed: 117.8 batches/s | ETA: 04:09
#   Train: [28200/57525] ( 49.0%) | Loss: 0.8824 | Speed: 117.8 batches/s | ETA: 04:08
#   Train: [28300/57525] ( 49.2%) | Loss: 0.8822 | Speed: 117.8 batches/s | ETA: 04:08
#   Train: [28400/57525] ( 49.4%) | Loss: 0.8820 | Speed: 117.8 batches/s | ETA: 04:07
#   Train: [28500/57525] ( 49.5%) | Loss: 0.8818 | Speed: 117.8 batches/s | ETA: 04:06
#   Train: [28600/57525] ( 49.7%) | Loss: 0.8816 | Speed: 117.8 batches/s | ETA: 04:05
#   Train: [28700/57525] ( 49.9%) | Loss: 0.8815 | Speed: 117.8 batches/s | ETA: 04:04
#   Train: [28800/57525] ( 50.1%) | Loss: 0.8813 | Speed: 117.8 batches/s | ETA: 04:03
#   Train: [28900/57525] ( 50.2%) | Loss: 0.8811 | Speed: 117.9 batches/s | ETA: 04:02
#   Train: [29000/57525] ( 50.4%) | Loss: 0.8810 | Speed: 117.9 batches/s | ETA: 04:01
#   Train: [29100/57525] ( 50.6%) | Loss: 0.8807 | Speed: 117.9 batches/s | ETA: 04:01
#   Train: [29200/57525] ( 50.8%) | Loss: 0.8805 | Speed: 118.0 batches/s | ETA: 04:00
#   Train: [29300/57525] ( 50.9%) | Loss: 0.8803 | Speed: 118.0 batches/s | ETA: 03:59
#   Train: [29400/57525] ( 51.1%) | Loss: 0.8801 | Speed: 118.0 batches/s | ETA: 03:58
#   Train: [29500/57525] ( 51.3%) | Loss: 0.8799 | Speed: 118.0 batches/s | ETA: 03:57
#   Train: [29600/57525] ( 51.5%) | Loss: 0.8796 | Speed: 118.1 batches/s | ETA: 03:56
#   Train: [29700/57525] ( 51.6%) | Loss: 0.8793 | Speed: 118.1 batches/s | ETA: 03:55
#   Train: [29800/57525] ( 51.8%) | Loss: 0.8792 | Speed: 118.1 batches/s | ETA: 03:54
#   Train: [29900/57525] ( 52.0%) | Loss: 0.8789 | Speed: 118.2 batches/s | ETA: 03:53
#   Train: [30000/57525] ( 52.2%) | Loss: 0.8787 | Speed: 118.2 batches/s | ETA: 03:52
#   Train: [30100/57525] ( 52.3%) | Loss: 0.8786 | Speed: 118.2 batches/s | ETA: 03:51
#   Train: [30200/57525] ( 52.5%) | Loss: 0.8783 | Speed: 118.3 batches/s | ETA: 03:51
#   Train: [30300/57525] ( 52.7%) | Loss: 0.8781 | Speed: 118.3 batches/s | ETA: 03:50
#   Train: [30400/57525] ( 52.8%) | Loss: 0.8779 | Speed: 118.3 batches/s | ETA: 03:49
#   Train: [30500/57525] ( 53.0%) | Loss: 0.8777 | Speed: 118.3 batches/s | ETA: 03:48
#   Train: [30600/57525] ( 53.2%) | Loss: 0.8775 | Speed: 118.4 batches/s | ETA: 03:47
#   Train: [30700/57525] ( 53.4%) | Loss: 0.8773 | Speed: 118.4 batches/s | ETA: 03:46
#   Train: [30800/57525] ( 53.5%) | Loss: 0.8771 | Speed: 118.4 batches/s | ETA: 03:45
#   Train: [30900/57525] ( 53.7%) | Loss: 0.8769 | Speed: 118.4 batches/s | ETA: 03:44
#   Train: [31000/57525] ( 53.9%) | Loss: 0.8767 | Speed: 118.5 batches/s | ETA: 03:43
#   Train: [31100/57525] ( 54.1%) | Loss: 0.8765 | Speed: 118.5 batches/s | ETA: 03:43
#   Train: [31200/57525] ( 54.2%) | Loss: 0.8763 | Speed: 118.5 batches/s | ETA: 03:42
#   Train: [31300/57525] ( 54.4%) | Loss: 0.8761 | Speed: 118.6 batches/s | ETA: 03:41
#   Train: [31400/57525] ( 54.6%) | Loss: 0.8760 | Speed: 118.6 batches/s | ETA: 03:40
#   Train: [31500/57525] ( 54.8%) | Loss: 0.8758 | Speed: 118.6 batches/s | ETA: 03:39
#   Train: [31600/57525] ( 54.9%) | Loss: 0.8756 | Speed: 118.6 batches/s | ETA: 03:38
#   Train: [31700/57525] ( 55.1%) | Loss: 0.8754 | Speed: 118.7 batches/s | ETA: 03:37
#   Train: [31800/57525] ( 55.3%) | Loss: 0.8752 | Speed: 118.7 batches/s | ETA: 03:36
#   Train: [31900/57525] ( 55.5%) | Loss: 0.8751 | Speed: 118.7 batches/s | ETA: 03:35
#   Train: [32000/57525] ( 55.6%) | Loss: 0.8748 | Speed: 118.7 batches/s | ETA: 03:34
#   Train: [32100/57525] ( 55.8%) | Loss: 0.8747 | Speed: 118.8 batches/s | ETA: 03:34
#   Train: [32200/57525] ( 56.0%) | Loss: 0.8745 | Speed: 118.8 batches/s | ETA: 03:33
#   Train: [32300/57525] ( 56.1%) | Loss: 0.8744 | Speed: 118.8 batches/s | ETA: 03:32
#   Train: [32400/57525] ( 56.3%) | Loss: 0.8742 | Speed: 118.8 batches/s | ETA: 03:31
#   Train: [32500/57525] ( 56.5%) | Loss: 0.8740 | Speed: 118.9 batches/s | ETA: 03:30
#   Train: [32600/57525] ( 56.7%) | Loss: 0.8739 | Speed: 118.9 batches/s | ETA: 03:29
#   Train: [32700/57525] ( 56.8%) | Loss: 0.8737 | Speed: 118.9 batches/s | ETA: 03:28
#   Train: [32800/57525] ( 57.0%) | Loss: 0.8735 | Speed: 118.9 batches/s | ETA: 03:27
#   Train: [32900/57525] ( 57.2%) | Loss: 0.8732 | Speed: 119.0 batches/s | ETA: 03:26
#   Train: [33000/57525] ( 57.4%) | Loss: 0.8730 | Speed: 119.0 batches/s | ETA: 03:26
#   Train: [33100/57525] ( 57.5%) | Loss: 0.8729 | Speed: 119.0 batches/s | ETA: 03:25
#   Train: [33200/57525] ( 57.7%) | Loss: 0.8727 | Speed: 119.0 batches/s | ETA: 03:24
#   Train: [33300/57525] ( 57.9%) | Loss: 0.8725 | Speed: 119.1 batches/s | ETA: 03:23
#   Train: [33400/57525] ( 58.1%) | Loss: 0.8724 | Speed: 119.1 batches/s | ETA: 03:22
#   Train: [33500/57525] ( 58.2%) | Loss: 0.8721 | Speed: 119.1 batches/s | ETA: 03:21
#   Train: [33600/57525] ( 58.4%) | Loss: 0.8719 | Speed: 119.1 batches/s | ETA: 03:20
#   Train: [33700/57525] ( 58.6%) | Loss: 0.8717 | Speed: 119.2 batches/s | ETA: 03:19
#   Train: [33800/57525] ( 58.8%) | Loss: 0.8716 | Speed: 119.2 batches/s | ETA: 03:19
#   Train: [33900/57525] ( 58.9%) | Loss: 0.8714 | Speed: 119.2 batches/s | ETA: 03:18
#   Train: [34000/57525] ( 59.1%) | Loss: 0.8712 | Speed: 119.2 batches/s | ETA: 03:17
#   Train: [34100/57525] ( 59.3%) | Loss: 0.8710 | Speed: 119.2 batches/s | ETA: 03:16
#   Train: [34200/57525] ( 59.5%) | Loss: 0.8708 | Speed: 119.2 batches/s | ETA: 03:15
#   Train: [34300/57525] ( 59.6%) | Loss: 0.8706 | Speed: 119.2 batches/s | ETA: 03:14
#   Train: [34400/57525] ( 59.8%) | Loss: 0.8704 | Speed: 119.2 batches/s | ETA: 03:14
#   Train: [34500/57525] ( 60.0%) | Loss: 0.8702 | Speed: 119.2 batches/s | ETA: 03:13
#   Train: [34600/57525] ( 60.1%) | Loss: 0.8700 | Speed: 119.2 batches/s | ETA: 03:12
#   Train: [34700/57525] ( 60.3%) | Loss: 0.8700 | Speed: 119.3 batches/s | ETA: 03:11
#   Train: [34800/57525] ( 60.5%) | Loss: 0.8699 | Speed: 119.3 batches/s | ETA: 03:10
#   Train: [34900/57525] ( 60.7%) | Loss: 0.8697 | Speed: 119.3 batches/s | ETA: 03:09
#   Train: [35000/57525] ( 60.8%) | Loss: 0.8695 | Speed: 119.3 batches/s | ETA: 03:08
#   Train: [35100/57525] ( 61.0%) | Loss: 0.8693 | Speed: 119.4 batches/s | ETA: 03:07
#   Train: [35200/57525] ( 61.2%) | Loss: 0.8692 | Speed: 119.4 batches/s | ETA: 03:07
#   Train: [35300/57525] ( 61.4%) | Loss: 0.8690 | Speed: 119.4 batches/s | ETA: 03:06
#   Train: [35400/57525] ( 61.5%) | Loss: 0.8688 | Speed: 119.4 batches/s | ETA: 03:05
#   Train: [35500/57525] ( 61.7%) | Loss: 0.8686 | Speed: 119.4 batches/s | ETA: 03:04
#   Train: [35600/57525] ( 61.9%) | Loss: 0.8684 | Speed: 119.5 batches/s | ETA: 03:03
#   Train: [35700/57525] ( 62.1%) | Loss: 0.8682 | Speed: 119.5 batches/s | ETA: 03:02
#   Train: [35800/57525] ( 62.2%) | Loss: 0.8680 | Speed: 119.5 batches/s | ETA: 03:01
#   Train: [35900/57525] ( 62.4%) | Loss: 0.8677 | Speed: 119.5 batches/s | ETA: 03:00
#   Train: [36000/57525] ( 62.6%) | Loss: 0.8675 | Speed: 119.6 batches/s | ETA: 03:00
#   Train: [36100/57525] ( 62.8%) | Loss: 0.8673 | Speed: 119.6 batches/s | ETA: 02:59
#   Train: [36200/57525] ( 62.9%) | Loss: 0.8671 | Speed: 119.6 batches/s | ETA: 02:58
#   Train: [36300/57525] ( 63.1%) | Loss: 0.8669 | Speed: 119.6 batches/s | ETA: 02:57
#   Train: [36400/57525] ( 63.3%) | Loss: 0.8668 | Speed: 119.6 batches/s | ETA: 02:56
#   Train: [36500/57525] ( 63.5%) | Loss: 0.8666 | Speed: 119.7 batches/s | ETA: 02:55
#   Train: [36600/57525] ( 63.6%) | Loss: 0.8664 | Speed: 119.7 batches/s | ETA: 02:54
#   Train: [36700/57525] ( 63.8%) | Loss: 0.8662 | Speed: 119.7 batches/s | ETA: 02:53
#   Train: [36800/57525] ( 64.0%) | Loss: 0.8661 | Speed: 119.7 batches/s | ETA: 02:53
#   Train: [36900/57525] ( 64.1%) | Loss: 0.8659 | Speed: 119.8 batches/s | ETA: 02:52
#   Train: [37000/57525] ( 64.3%) | Loss: 0.8658 | Speed: 119.8 batches/s | ETA: 02:51
#   Train: [37100/57525] ( 64.5%) | Loss: 0.8656 | Speed: 119.8 batches/s | ETA: 02:50
#   Train: [37200/57525] ( 64.7%) | Loss: 0.8654 | Speed: 119.8 batches/s | ETA: 02:49
#   Train: [37300/57525] ( 64.8%) | Loss: 0.8652 | Speed: 119.8 batches/s | ETA: 02:48
#   Train: [37400/57525] ( 65.0%) | Loss: 0.8651 | Speed: 119.9 batches/s | ETA: 02:47
#   Train: [37500/57525] ( 65.2%) | Loss: 0.8649 | Speed: 119.9 batches/s | ETA: 02:47
#   Train: [37600/57525] ( 65.4%) | Loss: 0.8647 | Speed: 119.9 batches/s | ETA: 02:46
#   Train: [37700/57525] ( 65.5%) | Loss: 0.8645 | Speed: 119.9 batches/s | ETA: 02:45
#   Train: [37800/57525] ( 65.7%) | Loss: 0.8643 | Speed: 119.9 batches/s | ETA: 02:44
#   Train: [37900/57525] ( 65.9%) | Loss: 0.8641 | Speed: 119.9 batches/s | ETA: 02:43
#   Train: [38000/57525] ( 66.1%) | Loss: 0.8640 | Speed: 119.9 batches/s | ETA: 02:42
#   Train: [38100/57525] ( 66.2%) | Loss: 0.8638 | Speed: 119.9 batches/s | ETA: 02:41
#   Train: [38200/57525] ( 66.4%) | Loss: 0.8635 | Speed: 119.9 batches/s | ETA: 02:41
#   Train: [38300/57525] ( 66.6%) | Loss: 0.8634 | Speed: 119.9 batches/s | ETA: 02:40
#   Train: [38400/57525] ( 66.8%) | Loss: 0.8633 | Speed: 120.0 batches/s | ETA: 02:39
#   Train: [38500/57525] ( 66.9%) | Loss: 0.8631 | Speed: 120.0 batches/s | ETA: 02:38
#   Train: [38600/57525] ( 67.1%) | Loss: 0.8629 | Speed: 120.0 batches/s | ETA: 02:37
#   Train: [38700/57525] ( 67.3%) | Loss: 0.8628 | Speed: 120.0 batches/s | ETA: 02:36
#   Train: [38800/57525] ( 67.4%) | Loss: 0.8626 | Speed: 120.0 batches/s | ETA: 02:35
#   Train: [38900/57525] ( 67.6%) | Loss: 0.8625 | Speed: 120.1 batches/s | ETA: 02:35
#   Train: [39000/57525] ( 67.8%) | Loss: 0.8623 | Speed: 120.1 batches/s | ETA: 02:34
#   Train: [39100/57525] ( 68.0%) | Loss: 0.8621 | Speed: 120.1 batches/s | ETA: 02:33
#   Train: [39200/57525] ( 68.1%) | Loss: 0.8620 | Speed: 120.1 batches/s | ETA: 02:32
#   Train: [39300/57525] ( 68.3%) | Loss: 0.8618 | Speed: 120.1 batches/s | ETA: 02:31
#   Train: [39400/57525] ( 68.5%) | Loss: 0.8616 | Speed: 120.2 batches/s | ETA: 02:30
#   Train: [39500/57525] ( 68.7%) | Loss: 0.8615 | Speed: 120.2 batches/s | ETA: 02:29
#   Train: [39600/57525] ( 68.8%) | Loss: 0.8613 | Speed: 120.2 batches/s | ETA: 02:29
#   Train: [39700/57525] ( 69.0%) | Loss: 0.8613 | Speed: 120.2 batches/s | ETA: 02:28
#   Train: [39800/57525] ( 69.2%) | Loss: 0.8611 | Speed: 120.2 batches/s | ETA: 02:27
#   Train: [39900/57525] ( 69.4%) | Loss: 0.8610 | Speed: 120.2 batches/s | ETA: 02:26
#   Train: [40000/57525] ( 69.5%) | Loss: 0.8609 | Speed: 120.3 batches/s | ETA: 02:25
#   Train: [40100/57525] ( 69.7%) | Loss: 0.8607 | Speed: 120.3 batches/s | ETA: 02:24
#   Train: [40200/57525] ( 69.9%) | Loss: 0.8605 | Speed: 120.3 batches/s | ETA: 02:24
#   Train: [40300/57525] ( 70.1%) | Loss: 0.8604 | Speed: 120.3 batches/s | ETA: 02:23
#   Train: [40400/57525] ( 70.2%) | Loss: 0.8602 | Speed: 120.3 batches/s | ETA: 02:22
#   Train: [40500/57525] ( 70.4%) | Loss: 0.8601 | Speed: 120.3 batches/s | ETA: 02:21
#   Train: [40600/57525] ( 70.6%) | Loss: 0.8599 | Speed: 120.4 batches/s | ETA: 02:20
#   Train: [40700/57525] ( 70.8%) | Loss: 0.8597 | Speed: 120.4 batches/s | ETA: 02:19
#   Train: [40800/57525] ( 70.9%) | Loss: 0.8595 | Speed: 120.4 batches/s | ETA: 02:18
#   Train: [40900/57525] ( 71.1%) | Loss: 0.8594 | Speed: 120.4 batches/s | ETA: 02:18
#   Train: [41000/57525] ( 71.3%) | Loss: 0.8592 | Speed: 120.4 batches/s | ETA: 02:17
#   Train: [41100/57525] ( 71.4%) | Loss: 0.8591 | Speed: 120.5 batches/s | ETA: 02:16
#   Train: [41200/57525] ( 71.6%) | Loss: 0.8590 | Speed: 120.5 batches/s | ETA: 02:15
#   Train: [41300/57525] ( 71.8%) | Loss: 0.8588 | Speed: 120.5 batches/s | ETA: 02:14
#   Train: [41400/57525] ( 72.0%) | Loss: 0.8587 | Speed: 120.5 batches/s | ETA: 02:13
#   Train: [41500/57525] ( 72.1%) | Loss: 0.8585 | Speed: 120.5 batches/s | ETA: 02:12
#   Train: [41600/57525] ( 72.3%) | Loss: 0.8584 | Speed: 120.5 batches/s | ETA: 02:12
#   Train: [41700/57525] ( 72.5%) | Loss: 0.8582 | Speed: 120.6 batches/s | ETA: 02:11
#   Train: [41800/57525] ( 72.7%) | Loss: 0.8580 | Speed: 120.6 batches/s | ETA: 02:10
#   Train: [41900/57525] ( 72.8%) | Loss: 0.8579 | Speed: 120.6 batches/s | ETA: 02:09
#   Train: [42000/57525] ( 73.0%) | Loss: 0.8577 | Speed: 120.6 batches/s | ETA: 02:08
#   Train: [42100/57525] ( 73.2%) | Loss: 0.8576 | Speed: 120.6 batches/s | ETA: 02:07
#   Train: [42200/57525] ( 73.4%) | Loss: 0.8576 | Speed: 120.6 batches/s | ETA: 02:07
#   Train: [42300/57525] ( 73.5%) | Loss: 0.8574 | Speed: 120.6 batches/s | ETA: 02:06
#   Train: [42400/57525] ( 73.7%) | Loss: 0.8574 | Speed: 120.6 batches/s | ETA: 02:05
#   Train: [42500/57525] ( 73.9%) | Loss: 0.8572 | Speed: 120.6 batches/s | ETA: 02:04
#   Train: [42600/57525] ( 74.1%) | Loss: 0.8570 | Speed: 120.7 batches/s | ETA: 02:03
#   Train: [42700/57525] ( 74.2%) | Loss: 0.8568 | Speed: 120.6 batches/s | ETA: 02:02
#   Train: [42800/57525] ( 74.4%) | Loss: 0.8567 | Speed: 120.7 batches/s | ETA: 02:02
#   Train: [42900/57525] ( 74.6%) | Loss: 0.8566 | Speed: 120.7 batches/s | ETA: 02:01
#   Train: [43000/57525] ( 74.8%) | Loss: 0.8564 | Speed: 120.7 batches/s | ETA: 02:00
#   Train: [43100/57525] ( 74.9%) | Loss: 0.8563 | Speed: 120.7 batches/s | ETA: 01:59
#   Train: [43200/57525] ( 75.1%) | Loss: 0.8562 | Speed: 120.7 batches/s | ETA: 01:58
#   Train: [43300/57525] ( 75.3%) | Loss: 0.8560 | Speed: 120.7 batches/s | ETA: 01:57
#   Train: [43400/57525] ( 75.4%) | Loss: 0.8558 | Speed: 120.8 batches/s | ETA: 01:56
#   Train: [43500/57525] ( 75.6%) | Loss: 0.8556 | Speed: 120.8 batches/s | ETA: 01:56
#   Train: [43600/57525] ( 75.8%) | Loss: 0.8555 | Speed: 120.8 batches/s | ETA: 01:55
#   Train: [43700/57525] ( 76.0%) | Loss: 0.8554 | Speed: 120.8 batches/s | ETA: 01:54
#   Train: [43800/57525] ( 76.1%) | Loss: 0.8552 | Speed: 120.8 batches/s | ETA: 01:53
#   Train: [43900/57525] ( 76.3%) | Loss: 0.8550 | Speed: 120.8 batches/s | ETA: 01:52
#   Train: [44000/57525] ( 76.5%) | Loss: 0.8549 | Speed: 120.9 batches/s | ETA: 01:51
#   Train: [44100/57525] ( 76.7%) | Loss: 0.8548 | Speed: 120.9 batches/s | ETA: 01:51
#   Train: [44200/57525] ( 76.8%) | Loss: 0.8546 | Speed: 120.9 batches/s | ETA: 01:50
#   Train: [44300/57525] ( 77.0%) | Loss: 0.8545 | Speed: 120.9 batches/s | ETA: 01:49
#   Train: [44400/57525] ( 77.2%) | Loss: 0.8543 | Speed: 120.9 batches/s | ETA: 01:48
#   Train: [44500/57525] ( 77.4%) | Loss: 0.8541 | Speed: 120.9 batches/s | ETA: 01:47
#   Train: [44600/57525] ( 77.5%) | Loss: 0.8539 | Speed: 120.9 batches/s | ETA: 01:46
#   Train: [44700/57525] ( 77.7%) | Loss: 0.8538 | Speed: 121.0 batches/s | ETA: 01:46
#   Train: [44800/57525] ( 77.9%) | Loss: 0.8537 | Speed: 121.0 batches/s | ETA: 01:45
#   Train: [44900/57525] ( 78.1%) | Loss: 0.8535 | Speed: 121.0 batches/s | ETA: 01:44
#   Train: [45000/57525] ( 78.2%) | Loss: 0.8534 | Speed: 121.0 batches/s | ETA: 01:43
#   Train: [45100/57525] ( 78.4%) | Loss: 0.8532 | Speed: 121.0 batches/s | ETA: 01:42
#   Train: [45200/57525] ( 78.6%) | Loss: 0.8530 | Speed: 121.0 batches/s | ETA: 01:41
#   Train: [45300/57525] ( 78.7%) | Loss: 0.8529 | Speed: 121.0 batches/s | ETA: 01:41
#   Train: [45400/57525] ( 78.9%) | Loss: 0.8527 | Speed: 121.0 batches/s | ETA: 01:40
#   Train: [45500/57525] ( 79.1%) | Loss: 0.8525 | Speed: 121.1 batches/s | ETA: 01:39
#   Train: [45600/57525] ( 79.3%) | Loss: 0.8524 | Speed: 121.1 batches/s | ETA: 01:38
#   Train: [45700/57525] ( 79.4%) | Loss: 0.8522 | Speed: 121.1 batches/s | ETA: 01:37
#   Train: [45800/57525] ( 79.6%) | Loss: 0.8521 | Speed: 121.1 batches/s | ETA: 01:36
#   Train: [45900/57525] ( 79.8%) | Loss: 0.8519 | Speed: 121.1 batches/s | ETA: 01:35
#   Train: [46000/57525] ( 80.0%) | Loss: 0.8517 | Speed: 121.1 batches/s | ETA: 01:35
#   Train: [46100/57525] ( 80.1%) | Loss: 0.8515 | Speed: 121.1 batches/s | ETA: 01:34
#   Train: [46200/57525] ( 80.3%) | Loss: 0.8514 | Speed: 121.1 batches/s | ETA: 01:33
#   Train: [46300/57525] ( 80.5%) | Loss: 0.8512 | Speed: 121.1 batches/s | ETA: 01:32
#   Train: [46400/57525] ( 80.7%) | Loss: 0.8510 | Speed: 121.1 batches/s | ETA: 01:31
#   Train: [46500/57525] ( 80.8%) | Loss: 0.8509 | Speed: 121.2 batches/s | ETA: 01:31
#   Train: [46600/57525] ( 81.0%) | Loss: 0.8508 | Speed: 121.2 batches/s | ETA: 01:30
#   Train: [46700/57525] ( 81.2%) | Loss: 0.8506 | Speed: 121.2 batches/s | ETA: 01:29
#   Train: [46800/57525] ( 81.4%) | Loss: 0.8505 | Speed: 121.2 batches/s | ETA: 01:28
#   Train: [46900/57525] ( 81.5%) | Loss: 0.8503 | Speed: 121.2 batches/s | ETA: 01:27
#   Train: [47000/57525] ( 81.7%) | Loss: 0.8501 | Speed: 121.2 batches/s | ETA: 01:26
#   Train: [47100/57525] ( 81.9%) | Loss: 0.8500 | Speed: 121.2 batches/s | ETA: 01:25
#   Train: [47200/57525] ( 82.1%) | Loss: 0.8499 | Speed: 121.2 batches/s | ETA: 01:25
#   Train: [47300/57525] ( 82.2%) | Loss: 0.8497 | Speed: 121.3 batches/s | ETA: 01:24
#   Train: [47400/57525] ( 82.4%) | Loss: 0.8496 | Speed: 121.3 batches/s | ETA: 01:23
#   Train: [47500/57525] ( 82.6%) | Loss: 0.8494 | Speed: 121.3 batches/s | ETA: 01:22
#   Train: [47600/57525] ( 82.7%) | Loss: 0.8493 | Speed: 121.3 batches/s | ETA: 01:21
#   Train: [47700/57525] ( 82.9%) | Loss: 0.8492 | Speed: 121.3 batches/s | ETA: 01:20
#   Train: [47800/57525] ( 83.1%) | Loss: 0.8491 | Speed: 121.3 batches/s | ETA: 01:20
#   Train: [47900/57525] ( 83.3%) | Loss: 0.8489 | Speed: 121.3 batches/s | ETA: 01:19
#   Train: [48000/57525] ( 83.4%) | Loss: 0.8488 | Speed: 121.4 batches/s | ETA: 01:18
#   Train: [48100/57525] ( 83.6%) | Loss: 0.8487 | Speed: 121.4 batches/s | ETA: 01:17
#   Train: [48200/57525] ( 83.8%) | Loss: 0.8485 | Speed: 121.4 batches/s | ETA: 01:16
#   Train: [48300/57525] ( 84.0%) | Loss: 0.8483 | Speed: 121.4 batches/s | ETA: 01:15
#   Train: [48400/57525] ( 84.1%) | Loss: 0.8482 | Speed: 121.4 batches/s | ETA: 01:15
#   Train: [48500/57525] ( 84.3%) | Loss: 0.8481 | Speed: 121.4 batches/s | ETA: 01:14
#   Train: [48600/57525] ( 84.5%) | Loss: 0.8479 | Speed: 121.4 batches/s | ETA: 01:13
#   Train: [48700/57525] ( 84.7%) | Loss: 0.8477 | Speed: 121.4 batches/s | ETA: 01:12
#   Train: [48800/57525] ( 84.8%) | Loss: 0.8476 | Speed: 121.5 batches/s | ETA: 01:11
#   Train: [48900/57525] ( 85.0%) | Loss: 0.8475 | Speed: 121.5 batches/s | ETA: 01:11
#   Train: [49000/57525] ( 85.2%) | Loss: 0.8474 | Speed: 121.5 batches/s | ETA: 01:10
#   Train: [49100/57525] ( 85.4%) | Loss: 0.8473 | Speed: 121.5 batches/s | ETA: 01:09
#   Train: [49200/57525] ( 85.5%) | Loss: 0.8471 | Speed: 121.5 batches/s | ETA: 01:08
#   Train: [49300/57525] ( 85.7%) | Loss: 0.8470 | Speed: 121.5 batches/s | ETA: 01:07
#   Train: [49400/57525] ( 85.9%) | Loss: 0.8469 | Speed: 121.5 batches/s | ETA: 01:06
#   Train: [49500/57525] ( 86.0%) | Loss: 0.8467 | Speed: 121.5 batches/s | ETA: 01:06
#   Train: [49600/57525] ( 86.2%) | Loss: 0.8466 | Speed: 121.5 batches/s | ETA: 01:05
#   Train: [49700/57525] ( 86.4%) | Loss: 0.8465 | Speed: 121.6 batches/s | ETA: 01:04
#   Train: [49800/57525] ( 86.6%) | Loss: 0.8463 | Speed: 121.6 batches/s | ETA: 01:03
#   Train: [49900/57525] ( 86.7%) | Loss: 0.8462 | Speed: 121.6 batches/s | ETA: 01:02
#   Train: [50000/57525] ( 86.9%) | Loss: 0.8460 | Speed: 121.6 batches/s | ETA: 01:01
#   Train: [50100/57525] ( 87.1%) | Loss: 0.8460 | Speed: 121.6 batches/s | ETA: 01:01
#   Train: [50200/57525] ( 87.3%) | Loss: 0.8458 | Speed: 121.6 batches/s | ETA: 01:00
#   Train: [50300/57525] ( 87.4%) | Loss: 0.8457 | Speed: 121.6 batches/s | ETA: 00:59
#   Train: [50400/57525] ( 87.6%) | Loss: 0.8456 | Speed: 121.6 batches/s | ETA: 00:58
#   Train: [50500/57525] ( 87.8%) | Loss: 0.8454 | Speed: 121.6 batches/s | ETA: 00:57
#   Train: [50600/57525] ( 88.0%) | Loss: 0.8452 | Speed: 121.6 batches/s | ETA: 00:56
#   Train: [50700/57525] ( 88.1%) | Loss: 0.8451 | Speed: 121.6 batches/s | ETA: 00:56
#   Train: [50800/57525] ( 88.3%) | Loss: 0.8450 | Speed: 121.6 batches/s | ETA: 00:55
#   Train: [50900/57525] ( 88.5%) | Loss: 0.8448 | Speed: 121.7 batches/s | ETA: 00:54
#   Train: [51000/57525] ( 88.7%) | Loss: 0.8447 | Speed: 121.7 batches/s | ETA: 00:53
#   Train: [51100/57525] ( 88.8%) | Loss: 0.8445 | Speed: 121.7 batches/s | ETA: 00:52
#   Train: [51200/57525] ( 89.0%) | Loss: 0.8444 | Speed: 121.7 batches/s | ETA: 00:51
#   Train: [51300/57525] ( 89.2%) | Loss: 0.8443 | Speed: 121.7 batches/s | ETA: 00:51
#   Train: [51400/57525] ( 89.4%) | Loss: 0.8442 | Speed: 121.7 batches/s | ETA: 00:50
#   Train: [51500/57525] ( 89.5%) | Loss: 0.8441 | Speed: 121.7 batches/s | ETA: 00:49
#   Train: [51600/57525] ( 89.7%) | Loss: 0.8440 | Speed: 121.7 batches/s | ETA: 00:48
#   Train: [51700/57525] ( 89.9%) | Loss: 0.8438 | Speed: 121.7 batches/s | ETA: 00:47
#   Train: [51800/57525] ( 90.0%) | Loss: 0.8437 | Speed: 121.7 batches/s | ETA: 00:47
#   Train: [51900/57525] ( 90.2%) | Loss: 0.8436 | Speed: 121.7 batches/s | ETA: 00:46
#   Train: [52000/57525] ( 90.4%) | Loss: 0.8435 | Speed: 121.7 batches/s | ETA: 00:45
#   Train: [52100/57525] ( 90.6%) | Loss: 0.8433 | Speed: 121.7 batches/s | ETA: 00:44
#   Train: [52200/57525] ( 90.7%) | Loss: 0.8431 | Speed: 121.7 batches/s | ETA: 00:43
#   Train: [52300/57525] ( 90.9%) | Loss: 0.8430 | Speed: 121.7 batches/s | ETA: 00:42
#   Train: [52400/57525] ( 91.1%) | Loss: 0.8428 | Speed: 121.7 batches/s | ETA: 00:42
#   Train: [52500/57525] ( 91.3%) | Loss: 0.8427 | Speed: 121.7 batches/s | ETA: 00:41
#   Train: [52600/57525] ( 91.4%) | Loss: 0.8426 | Speed: 121.7 batches/s | ETA: 00:40
#   Train: [52700/57525] ( 91.6%) | Loss: 0.8425 | Speed: 121.8 batches/s | ETA: 00:39
#   Train: [52800/57525] ( 91.8%) | Loss: 0.8423 | Speed: 121.8 batches/s | ETA: 00:38
#   Train: [52900/57525] ( 92.0%) | Loss: 0.8422 | Speed: 121.8 batches/s | ETA: 00:37
#   Train: [53000/57525] ( 92.1%) | Loss: 0.8421 | Speed: 121.8 batches/s | ETA: 00:37
#   Train: [53100/57525] ( 92.3%) | Loss: 0.8419 | Speed: 121.8 batches/s | ETA: 00:36
#   Train: [53200/57525] ( 92.5%) | Loss: 0.8418 | Speed: 121.8 batches/s | ETA: 00:35
#   Train: [53300/57525] ( 92.7%) | Loss: 0.8417 | Speed: 121.8 batches/s | ETA: 00:34
#   Train: [53400/57525] ( 92.8%) | Loss: 0.8415 | Speed: 121.8 batches/s | ETA: 00:33
#   Train: [53500/57525] ( 93.0%) | Loss: 0.8414 | Speed: 121.8 batches/s | ETA: 00:33
#   Train: [53600/57525] ( 93.2%) | Loss: 0.8413 | Speed: 121.9 batches/s | ETA: 00:32
#   Train: [53700/57525] ( 93.4%) | Loss: 0.8412 | Speed: 121.9 batches/s | ETA: 00:31
#   Train: [53800/57525] ( 93.5%) | Loss: 0.8411 | Speed: 121.9 batches/s | ETA: 00:30
#   Train: [53900/57525] ( 93.7%) | Loss: 0.8409 | Speed: 121.9 batches/s | ETA: 00:29
#   Train: [54000/57525] ( 93.9%) | Loss: 0.8408 | Speed: 121.9 batches/s | ETA: 00:28
#   Train: [54100/57525] ( 94.0%) | Loss: 0.8406 | Speed: 121.9 batches/s | ETA: 00:28
#   Train: [54200/57525] ( 94.2%) | Loss: 0.8405 | Speed: 121.9 batches/s | ETA: 00:27
#   Train: [54300/57525] ( 94.4%) | Loss: 0.8404 | Speed: 121.9 batches/s | ETA: 00:26
#   Train: [54400/57525] ( 94.6%) | Loss: 0.8402 | Speed: 121.9 batches/s | ETA: 00:25
#   Train: [54500/57525] ( 94.7%) | Loss: 0.8401 | Speed: 121.9 batches/s | ETA: 00:24
#   Train: [54600/57525] ( 94.9%) | Loss: 0.8399 | Speed: 122.0 batches/s | ETA: 00:23
#   Train: [54700/57525] ( 95.1%) | Loss: 0.8398 | Speed: 122.0 batches/s | ETA: 00:23
#   Train: [54800/57525] ( 95.3%) | Loss: 0.8396 | Speed: 122.0 batches/s | ETA: 00:22
#   Train: [54900/57525] ( 95.4%) | Loss: 0.8395 | Speed: 122.0 batches/s | ETA: 00:21
#   Train: [55000/57525] ( 95.6%) | Loss: 0.8394 | Speed: 122.0 batches/s | ETA: 00:20
#   Train: [55100/57525] ( 95.8%) | Loss: 0.8393 | Speed: 122.0 batches/s | ETA: 00:19
#   Train: [55200/57525] ( 96.0%) | Loss: 0.8392 | Speed: 122.0 batches/s | ETA: 00:19
#   Train: [55300/57525] ( 96.1%) | Loss: 0.8390 | Speed: 122.0 batches/s | ETA: 00:18
#   Train: [55400/57525] ( 96.3%) | Loss: 0.8390 | Speed: 122.0 batches/s | ETA: 00:17
#   Train: [55500/57525] ( 96.5%) | Loss: 0.8388 | Speed: 122.0 batches/s | ETA: 00:16
#   Train: [55600/57525] ( 96.7%) | Loss: 0.8386 | Speed: 122.1 batches/s | ETA: 00:15
#   Train: [55700/57525] ( 96.8%) | Loss: 0.8385 | Speed: 122.1 batches/s | ETA: 00:14
#   Train: [55800/57525] ( 97.0%) | Loss: 0.8383 | Speed: 122.1 batches/s | ETA: 00:14
#   Train: [55900/57525] ( 97.2%) | Loss: 0.8382 | Speed: 122.1 batches/s | ETA: 00:13
#   Train: [56000/57525] ( 97.3%) | Loss: 0.8381 | Speed: 122.1 batches/s | ETA: 00:12
#   Train: [56100/57525] ( 97.5%) | Loss: 0.8380 | Speed: 122.1 batches/s | ETA: 00:11
#   Train: [56200/57525] ( 97.7%) | Loss: 0.8379 | Speed: 122.1 batches/s | ETA: 00:10
#   Train: [56300/57525] ( 97.9%) | Loss: 0.8377 | Speed: 122.1 batches/s | ETA: 00:10
# ...
#   Train: [44100/57525] ( 76.7%) | Loss: 0.6738 | Speed: 106.4 batches/s | ETA: 02:06
#   Train: [44200/57525] ( 76.8%) | Loss: 0.6738 | Speed: 106.4 batches/s | ETA: 02:05
#   Train: [44300/57525] ( 77.0%) | Loss: 0.6738 | Speed: 106.5 batches/s | ETA: 02:04
#   Train: [44400/57525] ( 77.2%) | Loss: 0.6739 | Speed: 106.5 batches/s | ETA: 02:03
#   Train: [44500/57525] ( 77.4%) | Loss: 0.6738 | Speed: 106.5 batches/s | ETA: 02:02
#   Train: [44600/57525] ( 77.5%) | Loss: 0.6738 | Speed: 106.5 batches/s | ETA: 02:01
#   Train: [44700/57525] ( 77.7%) | Loss: 0.6738 | Speed: 106.5 batches/s | ETA: 02:00
#   Train: [44800/57525] ( 77.9%) | Loss: 0.6738 | Speed: 106.6 batches/s | ETA: 01:59
#   Train: [44900/57525] ( 78.1%) | Loss: 0.6738 | Speed: 106.6 batches/s | ETA: 01:58
#   Train: [45000/57525] ( 78.2%) | Loss: 0.6738 | Speed: 106.6 batches/s | ETA: 01:57
#   Train: [45100/57525] ( 78.4%) | Loss: 0.6738 | Speed: 106.6 batches/s | ETA: 01:56
#   Train: [45200/57525] ( 78.6%) | Loss: 0.6739 | Speed: 106.6 batches/s | ETA: 01:55
#   Train: [45300/57525] ( 78.7%) | Loss: 0.6738 | Speed: 106.7 batches/s | ETA: 01:54
#   Train: [45400/57525] ( 78.9%) | Loss: 0.6738 | Speed: 106.7 batches/s | ETA: 01:53
#   Train: [45500/57525] ( 79.1%) | Loss: 0.6738 | Speed: 106.7 batches/s | ETA: 01:52
#   Train: [45600/57525] ( 79.3%) | Loss: 0.6738 | Speed: 106.7 batches/s | ETA: 01:51
#   Train: [45700/57525] ( 79.4%) | Loss: 0.6738 | Speed: 106.7 batches/s | ETA: 01:50
#   Train: [45800/57525] ( 79.6%) | Loss: 0.6739 | Speed: 106.7 batches/s | ETA: 01:49
#   Train: [45900/57525] ( 79.8%) | Loss: 0.6739 | Speed: 106.7 batches/s | ETA: 01:48
#   Train: [46000/57525] ( 80.0%) | Loss: 0.6739 | Speed: 106.7 batches/s | ETA: 01:48
#   Train: [46100/57525] ( 80.1%) | Loss: 0.6738 | Speed: 106.7 batches/s | ETA: 01:47
#   Train: [46200/57525] ( 80.3%) | Loss: 0.6739 | Speed: 106.7 batches/s | ETA: 01:46
#   Train: [46300/57525] ( 80.5%) | Loss: 0.6738 | Speed: 106.7 batches/s | ETA: 01:45
#   Train: [46400/57525] ( 80.7%) | Loss: 0.6738 | Speed: 106.6 batches/s | ETA: 01:44
#   Train: [46500/57525] ( 80.8%) | Loss: 0.6738 | Speed: 106.6 batches/s | ETA: 01:43
#   Train: [46600/57525] ( 81.0%) | Loss: 0.6738 | Speed: 106.6 batches/s | ETA: 01:42
#   Train: [46700/57525] ( 81.2%) | Loss: 0.6738 | Speed: 106.6 batches/s | ETA: 01:41
#   Train: [46800/57525] ( 81.4%) | Loss: 0.6738 | Speed: 106.7 batches/s | ETA: 01:40
#   Train: [46900/57525] ( 81.5%) | Loss: 0.6738 | Speed: 106.7 batches/s | ETA: 01:39
#   Train: [47000/57525] ( 81.7%) | Loss: 0.6738 | Speed: 106.7 batches/s | ETA: 01:38
#   Train: [47100/57525] ( 81.9%) | Loss: 0.6738 | Speed: 106.7 batches/s | ETA: 01:37
#   Train: [47200/57525] ( 82.1%) | Loss: 0.6738 | Speed: 106.7 batches/s | ETA: 01:36
#   Train: [47300/57525] ( 82.2%) | Loss: 0.6738 | Speed: 106.7 batches/s | ETA: 01:35
#   Train: [47400/57525] ( 82.4%) | Loss: 0.6737 | Speed: 106.7 batches/s | ETA: 01:34
#   Train: [47500/57525] ( 82.6%) | Loss: 0.6737 | Speed: 106.7 batches/s | ETA: 01:33
#   Train: [47600/57525] ( 82.7%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:33
#   Train: [47700/57525] ( 82.9%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:32
#   Train: [47800/57525] ( 83.1%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:31
#   Train: [47900/57525] ( 83.3%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:30
#   Train: [48000/57525] ( 83.4%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:29
#   Train: [48100/57525] ( 83.6%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:28
#   Train: [48200/57525] ( 83.8%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:27
#   Train: [48300/57525] ( 84.0%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:26
#   Train: [48400/57525] ( 84.1%) | Loss: 0.6736 | Speed: 106.6 batches/s | ETA: 01:25
#   Train: [48500/57525] ( 84.3%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:24
#   Train: [48600/57525] ( 84.5%) | Loss: 0.6736 | Speed: 106.6 batches/s | ETA: 01:23
#   Train: [48700/57525] ( 84.7%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:22
#   Train: [48800/57525] ( 84.8%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:21
#   Train: [48900/57525] ( 85.0%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:20
#   Train: [49000/57525] ( 85.2%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:19
#   Train: [49100/57525] ( 85.4%) | Loss: 0.6738 | Speed: 106.6 batches/s | ETA: 01:19
#   Train: [49200/57525] ( 85.5%) | Loss: 0.6738 | Speed: 106.6 batches/s | ETA: 01:18
#   Train: [49300/57525] ( 85.7%) | Loss: 0.6738 | Speed: 106.6 batches/s | ETA: 01:17
#   Train: [49400/57525] ( 85.9%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:16
#   Train: [49500/57525] ( 86.0%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:15
#   Train: [49600/57525] ( 86.2%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:14
#   Train: [49700/57525] ( 86.4%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:13
#   Train: [49800/57525] ( 86.6%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:12
#   Train: [49900/57525] ( 86.7%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:11
#   Train: [50000/57525] ( 86.9%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:10
#   Train: [50100/57525] ( 87.1%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:09
#   Train: [50200/57525] ( 87.3%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:08
#   Train: [50300/57525] ( 87.4%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:07
#   Train: [50400/57525] ( 87.6%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:06
#   Train: [50500/57525] ( 87.8%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:05
#   Train: [50600/57525] ( 88.0%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:04
#   Train: [50700/57525] ( 88.1%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:04
#   Train: [50800/57525] ( 88.3%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:03
#   Train: [50900/57525] ( 88.5%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:02
#   Train: [51000/57525] ( 88.7%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:01
#   Train: [51100/57525] ( 88.8%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 01:00
#   Train: [51200/57525] ( 89.0%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 00:59
#   Train: [51300/57525] ( 89.2%) | Loss: 0.6738 | Speed: 106.6 batches/s | ETA: 00:58
#   Train: [51400/57525] ( 89.4%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 00:57
#   Train: [51500/57525] ( 89.5%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 00:56
#   Train: [51600/57525] ( 89.7%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 00:55
#   Train: [51700/57525] ( 89.9%) | Loss: 0.6737 | Speed: 106.6 batches/s | ETA: 00:54
#   Train: [51800/57525] ( 90.0%) | Loss: 0.6736 | Speed: 106.6 batches/s | ETA: 00:53
#   Train: [51900/57525] ( 90.2%) | Loss: 0.6736 | Speed: 106.6 batches/s | ETA: 00:52
#   Train: [52000/57525] ( 90.4%) | Loss: 0.6736 | Speed: 106.6 batches/s | ETA: 00:51
#   Train: [52100/57525] ( 90.6%) | Loss: 0.6736 | Speed: 106.6 batches/s | ETA: 00:50
#   Train: [52200/57525] ( 90.7%) | Loss: 0.6736 | Speed: 106.6 batches/s | ETA: 00:49
#   Train: [52300/57525] ( 90.9%) | Loss: 0.6736 | Speed: 106.6 batches/s | ETA: 00:49
#   Train: [52400/57525] ( 91.1%) | Loss: 0.6736 | Speed: 106.6 batches/s | ETA: 00:48
#   Train: [52500/57525] ( 91.3%) | Loss: 0.6736 | Speed: 106.6 batches/s | ETA: 00:47
#   Train: [52600/57525] ( 91.4%) | Loss: 0.6735 | Speed: 106.6 batches/s | ETA: 00:46
#   Train: [52700/57525] ( 91.6%) | Loss: 0.6735 | Speed: 106.6 batches/s | ETA: 00:45
#   Train: [52800/57525] ( 91.8%) | Loss: 0.6735 | Speed: 106.7 batches/s | ETA: 00:44
#   Train: [52900/57525] ( 92.0%) | Loss: 0.6735 | Speed: 106.7 batches/s | ETA: 00:43
#   Train: [53000/57525] ( 92.1%) | Loss: 0.6735 | Speed: 106.7 batches/s | ETA: 00:42
#   Train: [53100/57525] ( 92.3%) | Loss: 0.6735 | Speed: 106.7 batches/s | ETA: 00:41
#   Train: [53200/57525] ( 92.5%) | Loss: 0.6736 | Speed: 106.7 batches/s | ETA: 00:40
#   Train: [53300/57525] ( 92.7%) | Loss: 0.6736 | Speed: 106.8 batches/s | ETA: 00:39
#   Train: [53400/57525] ( 92.8%) | Loss: 0.6736 | Speed: 106.8 batches/s | ETA: 00:38
#   Train: [53500/57525] ( 93.0%) | Loss: 0.6736 | Speed: 106.8 batches/s | ETA: 00:37
#   Train: [53600/57525] ( 93.2%) | Loss: 0.6736 | Speed: 106.8 batches/s | ETA: 00:36
#   Train: [53700/57525] ( 93.4%) | Loss: 0.6736 | Speed: 106.9 batches/s | ETA: 00:35
#   Train: [53800/57525] ( 93.5%) | Loss: 0.6736 | Speed: 106.9 batches/s | ETA: 00:34
#   Train: [53900/57525] ( 93.7%) | Loss: 0.6736 | Speed: 106.9 batches/s | ETA: 00:33
#   Train: [54000/57525] ( 93.9%) | Loss: 0.6736 | Speed: 107.0 batches/s | ETA: 00:32
#   Train: [54100/57525] ( 94.0%) | Loss: 0.6736 | Speed: 107.0 batches/s | ETA: 00:32
#   Train: [54200/57525] ( 94.2%) | Loss: 0.6736 | Speed: 107.0 batches/s | ETA: 00:31
#   Train: [54300/57525] ( 94.4%) | Loss: 0.6736 | Speed: 107.0 batches/s | ETA: 00:30
#   Train: [54400/57525] ( 94.6%) | Loss: 0.6736 | Speed: 107.1 batches/s | ETA: 00:29
#   Train: [54500/57525] ( 94.7%) | Loss: 0.6736 | Speed: 107.1 batches/s | ETA: 00:28
#   Train: [54600/57525] ( 94.9%) | Loss: 0.6736 | Speed: 107.1 batches/s | ETA: 00:27
#   Train: [54700/57525] ( 95.1%) | Loss: 0.6736 | Speed: 107.2 batches/s | ETA: 00:26
#   Train: [54800/57525] ( 95.3%) | Loss: 0.6735 | Speed: 107.2 batches/s | ETA: 00:25
#   Train: [54900/57525] ( 95.4%) | Loss: 0.6736 | Speed: 107.2 batches/s | ETA: 00:24
#   Train: [55000/57525] ( 95.6%) | Loss: 0.6736 | Speed: 107.2 batches/s | ETA: 00:23
#   Train: [55100/57525] ( 95.8%) | Loss: 0.6735 | Speed: 107.3 batches/s | ETA: 00:22
#   Train: [55200/57525] ( 96.0%) | Loss: 0.6735 | Speed: 107.3 batches/s | ETA: 00:21
#   Train: [55300/57525] ( 96.1%) | Loss: 0.6735 | Speed: 107.3 batches/s | ETA: 00:20
#   Train: [55400/57525] ( 96.3%) | Loss: 0.6735 | Speed: 107.3 batches/s | ETA: 00:19
#   Train: [55500/57525] ( 96.5%) | Loss: 0.6735 | Speed: 107.4 batches/s | ETA: 00:18
#   Train: [55600/57525] ( 96.7%) | Loss: 0.6735 | Speed: 107.4 batches/s | ETA: 00:17
#   Train: [55700/57525] ( 96.8%) | Loss: 0.6735 | Speed: 107.4 batches/s | ETA: 00:16
#   Train: [55800/57525] ( 97.0%) | Loss: 0.6736 | Speed: 107.5 batches/s | ETA: 00:16
#   Train: [55900/57525] ( 97.2%) | Loss: 0.6735 | Speed: 107.5 batches/s | ETA: 00:15
#   Train: [56000/57525] ( 97.3%) | Loss: 0.6736 | Speed: 107.5 batches/s | ETA: 00:14
#   Train: [56100/57525] ( 97.5%) | Loss: 0.6735 | Speed: 107.5 batches/s | ETA: 00:13
#   Train: [56200/57525] ( 97.7%) | Loss: 0.6735 | Speed: 107.6 batches/s | ETA: 00:12
#   Train: [56300/57525] ( 97.9%) | Loss: 0.6735 | Speed: 107.6 batches/s | ETA: 00:11
#   Train: [56400/57525] ( 98.0%) | Loss: 0.6735 | Speed: 107.6 batches/s | ETA: 00:10
#   Train: [56500/57525] ( 98.2%) | Loss: 0.6736 | Speed: 107.6 batches/s | ETA: 00:09
#   Train: [56600/57525] ( 98.4%) | Loss: 0.6736 | Speed: 107.7 batches/s | ETA: 00:08
#   Train: [56700/57525] ( 98.6%) | Loss: 0.6736 | Speed: 107.7 batches/s | ETA: 00:07
#   Train: [56800/57525] ( 98.7%) | Loss: 0.6736 | Speed: 107.7 batches/s | ETA: 00:06
#   Train: [56900/57525] ( 98.9%) | Loss: 0.6736 | Speed: 107.8 batches/s | ETA: 00:05
#   Train: [57000/57525] ( 99.1%) | Loss: 0.6736 | Speed: 107.8 batches/s | ETA: 00:04
#   Train: [57100/57525] ( 99.3%) | Loss: 0.6736 | Speed: 107.8 batches/s | ETA: 00:03
#   Train: [57200/57525] ( 99.4%) | Loss: 0.6736 | Speed: 107.8 batches/s | ETA: 00:03
#   Train: [57300/57525] ( 99.6%) | Loss: 0.6736 | Speed: 107.9 batches/s | ETA: 00:02
#   Train: [57400/57525] ( 99.8%) | Loss: 0.6735 | Speed: 107.9 batches/s | ETA: 00:01
#   Train: [57500/57525] (100.0%) | Loss: 0.6735 | Speed: 107.9 batches/s | ETA: 00:00
#   Running validation...
#     Val: [  50/7191] (  0.7%)
#     Val: [ 100/7191] (  1.4%)
#     Val: [ 150/7191] (  2.1%)
#     Val: [ 200/7191] (  2.8%)
#     Val: [ 250/7191] (  3.5%)
#     Val: [ 300/7191] (  4.2%)
#     Val: [ 350/7191] (  4.9%)
#     Val: [ 400/7191] (  5.6%)
#     Val: [ 450/7191] (  6.3%)
#     Val: [ 500/7191] (  7.0%)
#     Val: [ 550/7191] (  7.6%)
#     Val: [ 600/7191] (  8.3%)
#     Val: [ 650/7191] (  9.0%)
#     Val: [ 700/7191] (  9.7%)
#     Val: [ 750/7191] ( 10.4%)
#     Val: [ 800/7191] ( 11.1%)
#     Val: [ 850/7191] ( 11.8%)
#     Val: [ 900/7191] ( 12.5%)
#     Val: [ 950/7191] ( 13.2%)
#     Val: [1000/7191] ( 13.9%)
#     Val: [1050/7191] ( 14.6%)
#     Val: [1100/7191] ( 15.3%)
#     Val: [1150/7191] ( 16.0%)
#     Val: [1200/7191] ( 16.7%)
#     Val: [1250/7191] ( 17.4%)
#     Val: [1300/7191] ( 18.1%)
#     Val: [1350/7191] ( 18.8%)
#     Val: [1400/7191] ( 19.5%)
#     Val: [1450/7191] ( 20.2%)
#     Val: [1500/7191] ( 20.9%)
#     Val: [1550/7191] ( 21.6%)
#     Val: [1600/7191] ( 22.3%)
#     Val: [1650/7191] ( 22.9%)
#     Val: [1700/7191] ( 23.6%)
#     Val: [1750/7191] ( 24.3%)
#     Val: [1800/7191] ( 25.0%)
#     Val: [1850/7191] ( 25.7%)
#     Val: [1900/7191] ( 26.4%)
#     Val: [1950/7191] ( 27.1%)
#     Val: [2000/7191] ( 27.8%)
#     Val: [2050/7191] ( 28.5%)
#     Val: [2100/7191] ( 29.2%)
#     Val: [2150/7191] ( 29.9%)
#     Val: [2200/7191] ( 30.6%)
#     Val: [2250/7191] ( 31.3%)
#     Val: [2300/7191] ( 32.0%)
#     Val: [2350/7191] ( 32.7%)
#     Val: [2400/7191] ( 33.4%)
#     Val: [2450/7191] ( 34.1%)
#     Val: [2500/7191] ( 34.8%)
#     Val: [2550/7191] ( 35.5%)
#     Val: [2600/7191] ( 36.2%)
#     Val: [2650/7191] ( 36.9%)
#     Val: [2700/7191] ( 37.5%)
#     Val: [2750/7191] ( 38.2%)
#     Val: [2800/7191] ( 38.9%)
#     Val: [2850/7191] ( 39.6%)
#     Val: [2900/7191] ( 40.3%)
#     Val: [2950/7191] ( 41.0%)
#     Val: [3000/7191] ( 41.7%)
#     Val: [3050/7191] ( 42.4%)
#     Val: [3100/7191] ( 43.1%)
#     Val: [3150/7191] ( 43.8%)
#     Val: [3200/7191] ( 44.5%)
#     Val: [3250/7191] ( 45.2%)
#     Val: [3300/7191] ( 45.9%)
#     Val: [3350/7191] ( 46.6%)
#     Val: [3400/7191] ( 47.3%)
#     Val: [3450/7191] ( 48.0%)
#     Val: [3500/7191] ( 48.7%)
#     Val: [3550/7191] ( 49.4%)
#     Val: [3600/7191] ( 50.1%)
#     Val: [3650/7191] ( 50.8%)
#     Val: [3700/7191] ( 51.5%)
#     Val: [3750/7191] ( 52.1%)
#     Val: [3800/7191] ( 52.8%)
#     Val: [3850/7191] ( 53.5%)
#     Val: [3900/7191] ( 54.2%)
#     Val: [3950/7191] ( 54.9%)
#     Val: [4000/7191] ( 55.6%)
#     Val: [4050/7191] ( 56.3%)
#     Val: [4100/7191] ( 57.0%)
#     Val: [4150/7191] ( 57.7%)
#     Val: [4200/7191] ( 58.4%)
#     Val: [4250/7191] ( 59.1%)
#     Val: [4300/7191] ( 59.8%)
#     Val: [4350/7191] ( 60.5%)
#     Val: [4400/7191] ( 61.2%)
#     Val: [4450/7191] ( 61.9%)
#     Val: [4500/7191] ( 62.6%)
#     Val: [4550/7191] ( 63.3%)
#     Val: [4600/7191] ( 64.0%)
#     Val: [4650/7191] ( 64.7%)
#     Val: [4700/7191] ( 65.4%)
#     Val: [4750/7191] ( 66.1%)
#     Val: [4800/7191] ( 66.8%)
#     Val: [4850/7191] ( 67.4%)
#     Val: [4900/7191] ( 68.1%)
#     Val: [4950/7191] ( 68.8%)
#     Val: [5000/7191] ( 69.5%)
#     Val: [5050/7191] ( 70.2%)
#     Val: [5100/7191] ( 70.9%)
#     Val: [5150/7191] ( 71.6%)
#     Val: [5200/7191] ( 72.3%)
#     Val: [5250/7191] ( 73.0%)
#     Val: [5300/7191] ( 73.7%)
#     Val: [5350/7191] ( 74.4%)
#     Val: [5400/7191] ( 75.1%)
#     Val: [5450/7191] ( 75.8%)
#     Val: [5500/7191] ( 76.5%)
#     Val: [5550/7191] ( 77.2%)
#     Val: [5600/7191] ( 77.9%)
#     Val: [5650/7191] ( 78.6%)
#     Val: [5700/7191] ( 79.3%)
#     Val: [5750/7191] ( 80.0%)
#     Val: [5800/7191] ( 80.7%)
#     Val: [5850/7191] ( 81.4%)
#     Val: [5900/7191] ( 82.0%)
#     Val: [5950/7191] ( 82.7%)
#     Val: [6000/7191] ( 83.4%)
#     Val: [6050/7191] ( 84.1%)
#     Val: [6100/7191] ( 84.8%)
#     Val: [6150/7191] ( 85.5%)
#     Val: [6200/7191] ( 86.2%)
#     Val: [6250/7191] ( 86.9%)
#     Val: [6300/7191] ( 87.6%)
#     Val: [6350/7191] ( 88.3%)
#     Val: [6400/7191] ( 89.0%)
#     Val: [6450/7191] ( 89.7%)
#     Val: [6500/7191] ( 90.4%)
#     Val: [6550/7191] ( 91.1%)
#     Val: [6600/7191] ( 91.8%)
#     Val: [6650/7191] ( 92.5%)
#     Val: [6700/7191] ( 93.2%)
#     Val: [6750/7191] ( 93.9%)
#     Val: [6800/7191] ( 94.6%)
#     Val: [6850/7191] ( 95.3%)
#     Val: [6900/7191] ( 96.0%)
#     Val: [6950/7191] ( 96.6%)
#     Val: [7000/7191] ( 97.3%)
#     Val: [7050/7191] ( 98.0%)
#     Val: [7100/7191] ( 98.7%)
#     Val: [7150/7191] ( 99.4%)
#
#   Epoch 20 Summary:
#     Train MSE (norm): 0.6736 | Val MSE (norm): 0.6329
#     Time: Train=8.9min, Val=0.2min, Total=9.1min
# ============================================================

# %%
def mse_doc(yhat, y):
    yhat = np.asarray(yhat, dtype=np.float64)
    y    = np.asarray(y,    dtype=np.float64)
    n = y.size
    return float(np.sum((y - yhat)**2) / n)

def pearson_doc(x, y):
    x = np.asarray(x, dtype=np.float64)
    y = np.asarray(y, dtype=np.float64)
    n      = x.size
    sum_x  = np.sum(x)
    sum_y  = np.sum(y)
    sum_xy = np.sum(x * y)
    sum_x2 = np.sum(x * x)
    sum_y2 = np.sum(y * y)
    denom = np.sqrt((n * sum_x2 - sum_x * sum_x) * (n * sum_y2 - sum_y * sum_y))
    return float((n * sum_xy - sum_x * sum_y) / denom) if denom != 0.0 else 0.0

def _ranks_avg(a):
    a = np.asarray(a, dtype=np.float64)
    order = np.argsort(a, kind="mergesort")
    ranks = np.empty_like(order, dtype=np.float64)
    sa = a[order]
    diff = np.concatenate(([True], sa[1:] != sa[:-1], [True]))
    idx = np.flatnonzero(diff)
    for s, e in zip(idx[:-1], idx[1:]):
        ranks[order[s:e]] = 0.5 * (s + e - 1) + 1.0
    return ranks

def spearman_doc(x, y):
    rx = _ranks_avg(x)
    ry = _ranks_avg(y)
    d  = rx - ry
    n  = rx.size
    denom = n * (n * n - 1.0)
    return float(1.0 - (6.0 * np.sum(d * d)) / denom) if denom != 0.0 else 0.0

def accuracy_direction(yhat, y):
    yhat = np.asarray(yhat, dtype=np.float64)
    y    = np.asarray(y,    dtype=np.float64)
    return float(np.mean((yhat >= 0) == (y >= 0)))

@torch.no_grad()
def preds_and_trues(indexes, batch_size=256):
    """
    Get predictions and true values. Predictions are de-normalized from normalized space.
    """
    model.eval()
    ps_norm, ys_norm = [], []
    for seq, cl, ph, ch, st, tgt_norm in iter_minibatches(indexes, batch_size=batch_size, shuffle=False, use_normalized=True):
        out_norm = model(seq, cl, ph, ch, st)
        ps_norm.append(out_norm.detach().cpu().numpy())
        ys_norm.append(tgt_norm.detach().cpu().numpy())
    
    yhat_norm = np.concatenate(ps_norm)
    y_norm = np.concatenate(ys_norm)

    yhat_real = yhat_norm * sigma + mu
    y_real = y_norm * sigma + mu
    
    return yhat_real, y_real

def eval_split(indexes):
    yhat, y = preds_and_trues(indexes, batch_size=256)
    return {
        "MSE": mse_doc(yhat, y),
        "Pearson": pearson_doc(yhat, y),
        "Spearman": spearman_doc(yhat, y),
        "Accuracy": accuracy_direction(yhat, y),
    }

# --- print results ---
print("Validation:", eval_split(idx_val))
print("Test:",       eval_split(idx_test))
# Out:
# Validation: {'MSE': 0.42015865735536656, 'Pearson': 0.6059171269430975, 'Spearman': 0.4450389401294309, 'Accuracy': 0.654711421558881}
# Test: {'MSE': 0.42129980467383743, 'Pearson': 0.6062832029035408, 'Spearman': 0.4458618969492417, 'Accuracy': 0.6549216582952245}
